# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# ## Project Description

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# Data Storage:
#
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
#
# Country_code.csv contains two variables:
# • Country code
# • Country name

# %% [markdown]
# The collected data has been stored in the Comma Separated Value file Zomato.csv.
#
#
# Each restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
#
# • Restaurant Name: Name of the restaurant
#
#
# • Country Code: Country in which restaurant is located
#
#
# • City: City in which restaurant is located
#
#
# • Address: Address of the restaurant
#
#
# • Locality: Location in the city
#
#
# • Locality Verbose: Detailed description of the locality
#
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
#
# • Cuisines: Cuisines offered by the restaurant
#
#
# • Average Cost for two: Cost for two people in different currencies ��
#
#
# • Currency: Currency of the country
#
#
# • Has Table booking: yes/no
#
#
# • Has Online delivery: yes/ no
#
#
# • Is delivering: yes/ no
#
#
# • Switch to order menu: yes/no
#
#
# • Price range: range of price of food
#
#
# • Aggregate Rating: Average rating out of 5
#
#
# • Rating color: depending upon the average rating color
#
#
# • Rating text: text on the basis of rating of rating
#
#
# • Votes: Number of ratings casted by people
#
#
# Problem statement : In this dataset predict 2 things –
#
#
# 1) Average Cost for two
#
#
# 2) Price range

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Impoting Datasets

# %%
df=pd.read_csv('zomoto.csv')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %% [markdown]
# This dataset has 9551 rows and 21 columns

# %%
df1=pd.read_excel('Country-Code.xlsx')
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# This dataset has 15 rows and 2 columns named country code, country

# %% [markdown]
# # Lets merge both the dataset

# %% [markdown]
# Both the dataset has country code as a common variable so we will merge both of this dataset on this column

# %%
df=pd.merge(df,df1, on='Country Code',how='left')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...  Has Table booking  \
# 0     14.565443        French, Japanese, Desserts  ...                Yes
# 1     14.553708                          Japanese  ...                Yes
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...                Yes
# 3     14.585318                   Japanese, Sushi  ...                 No
# 4     14.584450                  Japanese, Korean  ...                Yes
# ...         ...                               ...  ...                ...
# 9546  41.022793                           Turkish  ...                 No
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...                 No
# 9548  41.055817            Italian, World Cuisine  ...                 No
# 9549  41.057979                   Restaurant Cafe  ...                 No
# 9550  40.984776                              Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                     No                No                   No           3
# 1                     No                No                   No           3
# 2                     No                No                   No           4
# 3                     No                No                   No           4
# 4                     No                No                   No           4
# ...                  ...               ...                  ...         ...
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes      Country
# 0                 4.8    Dark Green    Excellent   314  Phillipines
# 1                 4.5    Dark Green    Excellent   591  Phillipines
# 2                 4.4         Green    Very Good   270  Phillipines
# 3                 4.9    Dark Green    Excellent   365  Phillipines
# 4                 4.8    Dark Green    Excellent   229  Phillipines
# ...               ...           ...          ...   ...          ...
# 9546              4.1         Green    Very Good   788       Turkey
# 9547              4.2         Green    Very Good  1034       Turkey
# 9548              3.7        Yellow         Good   661       Turkey
# 9549              4.0         Green    Very Good   901       Turkey
# 9550              4.0         Green    Very Good   591       Turkey
#
# [9551 rows x 22 columns]

# %% [markdown]
# Here we have merge both of the dataset

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# After merging both of the dataset we have 9551 rows and 22 columns.

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
# 5  Mandaluyong City  Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 6        Pasay City  Building K, SM By The Bay, Sunset Boulevard, M...
# 7        Pasay City  Building B, By The Bay, Seaside Boulevard, Mal...
# 8        Pasay City  Plaza Level, Sofitel Philippine Plaza Manila, ...
# 9        Pasig City  Brixton Technology Center, 10 Brixton Street, ...
#
#                                           Locality  \
# 0        Century City Mall, Poblacion, Makati City
# 1       Little Tokyo, Legaspi Village, Makati City
# 2       Edsa Shangri-La, Ortigas, Mandaluyong City
# 3           SM Megamall, Ortigas, Mandaluyong City
# 4           SM Megamall, Ortigas, Mandaluyong City
# 5           SM Megamall, Ortigas, Mandaluyong City
# 6  SM by the Bay, Mall of Asia Complex, Pasay City
# 7  SM by the Bay, Mall of Asia Complex, Pasay City
# 8      Sofitel Philippine Plaza Manila, Pasay City
# 9                                        Kapitolyo
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
# 5  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056314  14.583764
# 6  SM by the Bay, Mall of Asia Complex, Pasay Cit...  120.979667  14.531333
# 7  SM by the Bay, Mall of Asia Complex, Pasay Cit...  120.979333  14.540000
# 8  Sofitel Philippine Plaza Manila, Pasay City, P...  120.980090  14.552990
# 9                              Kapitolyo, Pasig City  121.056532  14.572041
#
#                              Cuisines  ...  Has Table booking  \
# 0          French, Japanese, Desserts  ...                Yes
# 1                            Japanese  ...                Yes
# 2    Seafood, Asian, Filipino, Indian  ...                Yes
# 3                     Japanese, Sushi  ...                 No
# 4                    Japanese, Korean  ...                Yes
# 5                             Chinese  ...                 No
# 6                     Asian, European  ...                Yes
# 7  Seafood, Filipino, Asian, European  ...                Yes
# 8             European, Asian, Indian  ...                Yes
# 9                            Filipino  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
# 5                  No                No                   No           3
# 6                  No                No                   No           4
# 7                  No                No                   No           4
# 8                  No                No                   No           4
# 9                  No                No                   No           3
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
# 3              4.9    Dark Green    Excellent   365  Phillipines
# 4              4.8    Dark Green    Excellent   229  Phillipines
# 5              4.4         Green    Very Good   336  Phillipines
# 6              4.0         Green    Very Good   520  Phillipines
# 7              4.2         Green    Very Good   677  Phillipines
# 8              4.9    Dark Green    Excellent   621  Phillipines
# 9              4.8    Dark Green    Excellent   532  Phillipines
#
# [10 rows x 22 columns]

# %% [markdown]
# Top 10 rows of the dataset

# %%
df.tail(10)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9541        5905215           Emirgan S�_ti��           208  ��stanbul
# 9542        5926979            Leman K�_lt�_r           208  ��stanbul
# 9543        5916085              Dem Karak�_y           208  ��stanbul
# 9544        5915547     Karak�_y G�_ll�_o��lu           208  ��stanbul
# 9545        5915054                  Baltazar           208  ��stanbul
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address         Locality  \
# 9541  Emirgan Mahallesi, Sak۱p Sabanc۱ Caddesi, No 4...         Emirg��n
# 9542  Cafera��a Mahallesi, Ne��et �_mer Sokak, No 9/...  Kad۱k�_y Merkez
# 9543  Kemanke�� Karamustafa Pa��a Mahallesi, Hoca Ta...         Karak�_y
# 9544  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...         Karak�_y
# 9545  Kemanke�� Karamustafa Pa��a Mahallesi, K۱l۱�_ ...         Karak�_y
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...         Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...        Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...      Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...      Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...             Moda
#
#                 Locality Verbose  Longitude   Latitude  \
# 9541         Emirg��n, ��stanbul  29.056620  41.104969
# 9542  Kad۱k�_y Merkez, ��stanbul  29.022805  40.989705
# 9543         Karak�_y, ��stanbul  28.978237  41.024633
# 9544         Karak�_y, ��stanbul  28.977636  41.022904
# 9545         Karak�_y, ��stanbul  28.981103  41.025785
# 9546         Karak�_y, ��stanbul  28.977392  41.022793
# 9547        Ko��uyolu, ��stanbul  29.041297  41.009847
# 9548      Kuru�_e��me, ��stanbul  29.034640  41.055817
# 9549      Kuru�_e��me, ��stanbul  29.036019  41.057979
# 9550             Moda, ��stanbul  29.026016  40.984776
#
#                                 Cuisines  ...  Has Table booking  \
# 9541  Restaurant Cafe, Turkish, Desserts  ...                 No
# 9542                     Restaurant Cafe  ...                 No
# 9543                                Cafe  ...                 No
# 9544                    Desserts, B�_rek  ...                 No
# 9545                      Burger, Izgara  ...                 No
# 9546                             Turkish  ...                 No
# 9547     World Cuisine, Patisserie, Cafe  ...                 No
# 9548              Italian, World Cuisine  ...                 No
# 9549                     Restaurant Cafe  ...                 No
# 9550                                Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 9541                  No                No                   No           3
# 9542                  No                No                   No           3
# 9543                  No                No                   No           2
# 9544                  No                No                   No           2
# 9545                  No                No                   No           3
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes Country
# 9541              4.2         Green    Very Good   877  Turkey
# 9542              3.7        Yellow         Good   506  Turkey
# 9543              4.5    Dark Green    Excellent   761  Turkey
# 9544              4.7    Dark Green    Excellent  1305  Turkey
# 9545              4.3         Green    Very Good   870  Turkey
# 9546              4.1         Green    Very Good   788  Turkey
# 9547              4.2         Green    Very Good  1034  Turkey
# 9548              3.7        Yellow         Good   661  Turkey
# 9549              4.0         Green    Very Good   901  Turkey
# 9550              4.0         Green    Very Good   591  Turkey
#
# [10 rows x 22 columns]

# %% [markdown]
# Last 10 rows of the dataset

# %%
df.sample(10)
# Out:
#       Restaurant ID          Restaurant Name  Country Code       City  \
# 1698           6743          Cafe Coffee Day             1    Gurgaon
# 5715           9269          Taj Mahal Dhaba             1  New Delhi
# 625         3400341      Rangrezz Restaurant             1       Agra
# 6860       18355141  Abdullah Biryani Centre             1  New Delhi
# 4559         306106          Boheme Cafe Bar             1  New Delhi
# 5472           5729                 Nirmal's             1  New Delhi
# 5226         301820              Spicy Tadka             1  New Delhi
# 9221        3200005             Little Italy             1   Vadodara
# 2993           7686            R. Ahmad Food             1  New Delhi
# 2038           5080           New Sukh Sagar             1    Gurgaon
#
#                                                 Address  \
# 1698            F-13, Qutub Plaza, DLF Phase 1, Gurgaon
# 5715       Deenpur Main Goyla Mod, Najafgarh, New Delhi
# 625   E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 6860     IGNOU Road, Neb Sarai, Sainik Farms, New Delhi
# 4559  16-A/1, WEA, Near Metro Station, Karol Bagh, N...
# 5472     Opposite NIIT, D Park, Model Town 3, New Delhi
# 5226  BE 332, Hari Nagar Street 3, Mayapuri Phase 2,...
# 9221  36, Alkapuri Society, Behind HDFC Bank, Alkapu...
# 2993    Community Centre, New Friends Colony, New Delhi
# 2038  CB-84, Shopping Mall, Arjun Marg, DLF Phase 1,...
#
#                                   Locality  \
# 1698              Qutab Plaza, DLF Phase 1
# 5715                             Najafgarh
# 625                             Agra Cantt
# 6860                          Sainik Farms
# 4559                            Karol Bagh
# 5472                          Model Town 3
# 5226                      Mayapuri Phase 2
# 9221                              Alkapuri
# 2993  Community Centre, New Friends Colony
# 2038            Shopping Mall, DLF Phase 1
#
#                                      Locality Verbose  Longitude   Latitude  \
# 1698                Qutab Plaza, DLF Phase 1, Gurgaon  77.101726  28.471807
# 5715                             Najafgarh, New Delhi  76.993205  28.590623
# 625                                  Agra Cantt, Agra   0.000000   0.000000
# 6860                          Sainik Farms, New Delhi  77.198759  28.505561
# 4559                            Karol Bagh, New Delhi  77.187292  28.645890
# 5472                          Model Town 3, New Delhi  77.185316  28.709292
# 5226                      Mayapuri Phase 2, New Delhi  77.119606  28.630817
# 9221                               Alkapuri, Vadodara  73.170283  22.312790
# 2993  Community Centre, New Friends Colony, New Delhi  77.269169  28.562686
# 2038              Shopping Mall, DLF Phase 1, Gurgaon  77.100018  28.465995
#
#                                          Cuisines  ...  Has Table booking  \
# 1698                                         Cafe  ...                 No
# 5715                                 North Indian  ...                 No
# 625                         North Indian, Mughlai  ...                 No
# 6860                                      Biryani  ...                 No
# 4559  North Indian, Chinese, Continental, Italian  ...                Yes
# 5472                                      Chinese  ...                 No
# 5226                        North Indian, Chinese  ...                 No
# 9221                                      Italian  ...                 No
# 2993                                 North Indian  ...                 No
# 2038                                  Street Food  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 1698                  No                No                   No           1
# 5715                  No                No                   No           1
# 625                   No                No                   No           2
# 6860                  No                No                   No           1
# 4559                 Yes                No                   No           3
# 5472                  No                No                   No           1
# 5226                 Yes                No                   No           2
# 9221                  No                No                   No           3
# 2993                  No                No                   No           1
# 2038                  No                No                   No           1
#
#      Aggregate rating  Rating color  Rating text Votes Country
# 1698              2.8        Orange      Average    18   India
# 5715              0.0         White    Not rated     2   India
# 625               3.5        Yellow         Good    71   India
# 6860              0.0         White    Not rated     1   India
# 4559              3.2        Orange      Average   142   India
# 5472              2.7        Orange      Average     9   India
# 5226              3.5        Yellow         Good    24   India
# 9221              4.1         Green    Very Good   202   India
# 2993              3.0        Orange      Average    11   India
# 2038              3.2        Orange      Average    16   India
#
# [10 rows x 22 columns]

# %% [markdown]
# 10 random rows from the dataset

# %% [markdown]
# # Exploratory Data Analysis [EDA]

# %%
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %% [markdown]
# list of all the columns present in the dataset.

# %% [markdown]
# # Checking for the various data types present in the dataset

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# There are 3 types of data present in the dataset ["int64", "object", "float64"]

# %% [markdown]
# # Check For Null Values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# As we can see here that column "Cuisines" has prescence of 9 null values.

# %%
#Visualization by heatmap
sns.heatmap(df.isnull(),  cmap='spring')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The null value present in the column "Cuisines" is very less that we can't clearly see it on heatmap so we will try another method

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(18,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =11)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# Here we can clearly see that "Cuisines" has prescence of null values.

# %%
print(df['Cuisines'].unique())
# Out:
# ['French, Japanese, Desserts' 'Japanese'
#  'Seafood, Asian, Filipino, Indian' ... 'Burger, Izgara'
#  'World Cuisine, Patisserie, Cafe' 'Italian, World Cuisine']

# %% [markdown]
# Here We cannot fill NaN Value Like that only by mode bcz every country have it own dishes which may or may not be provided in another country .. So we will fill it with no dishes in nan value place.

# %%
df['Cuisines']=df['Cuisines'].fillna("No Cuisines")

# %% [markdown]
# # Lets check again that the null values are filled or not

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(18,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =11)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# Here we can see that no null values are present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# Here we can get a general information about the dataset like total non-null value count which is same for each column which shows that there are no null values preent in the dataset, we can also see various data types present in the dataset, there are 3 types of the data present ['int64', 'object', 'float64']. we can also observe total number of columns present in the dataset there are total 22 columns present in the dataset & also we can see total memroy occupied by the dataset.

# %% [markdown]
# # Check for duplicate value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we can see here that there are no duplicated values prescent here.

# %% [markdown]
# # Check for white space

# %%
has_white_space=' '  in df
print(has_white_space)
# Out:
# False

# %% [markdown]
# There is no white space available in the dataset.

# %% [markdown]
# # Check for prescence of various symbols

# %%
df.isin([' ?']).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Symbol "?" is not present in the dataset.

# %%
df.isin(['@']).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Symbol "@" is not present in the dataset.

# %%
df.isin(['#']).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Symbol "#" is not present in the dataset

# %%
#Checking unique values of each column
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1826
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# We can observe unique value count for each column present in the dataset & We can observe the columns Restaurant ID have 9551 unique values which means they have only one value count. So it not required for the prediction so we can drop it.

# %% [markdown]
# Switch to order menu it has only one counts as 'No',and it is not contributing to target variable so we will remove it from the dataset.

# %%
df.drop("Switch to order menu",axis=1,inplace=True)

# %% [markdown]
# Dropping Restaurant ID column as it is not playing any role in analysis

# %%
# Dropping Restaurant ID columns
df.drop("Restaurant ID",axis=1,inplace=True)

# %% [markdown]
# We can also drop the address column from the dataset as it is not required to know exact address

# %%
df.drop("Address",axis=1,inplace=True)

# %% [markdown]
# # Check for value count for each column

# %%
# Value counts of each columns
for i in df.columns:
        print(df[i].value_counts())
        print('\n\n')
        print ('*'*100)
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
#
# ****************************************************************************************************
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
#
# ****************************************************************************************************
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64
#
#
#
# ****************************************************************************************************
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Malviya Nagar                                   85
#                                               ...
# Lemon Tree Premier, Sector 29                    1
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Moda                                             1
# Name: Locality, Length: 1208, dtype: int64
#
#
#
# ****************************************************************************************************
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda, ��stanbul                                 1
# Name: Locality Verbose, Length: 1265, dtype: int64
#
#
#
# ****************************************************************************************************
# 0.000000     498
# 77.353663     19
# 77.230412     12
# 77.088688     10
# 77.251426      9
#             ...
# 77.227294      1
# 77.225420      1
# 77.230347      1
# 77.230578      1
# 29.026016      1
# Name: Longitude, Length: 8120, dtype: int64
#
#
#
# ****************************************************************************************************
# 0.000000     498
# 28.574309     16
# 28.551456      9
# 28.574300      9
# 28.597103      8
#             ...
# 28.645175      1
# 28.646194      1
# 28.648280      1
# 28.643514      1
# 40.984776      1
# Name: Latitude, Length: 8677, dtype: int64
#
#
#
# ****************************************************************************************************
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1826, dtype: int64
#
#
#
# ****************************************************************************************************
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: Average Cost for two, Length: 140, dtype: int64
#
#
#
# ****************************************************************************************************
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64
#
#
#
# ****************************************************************************************************
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64
#
#
#
# ****************************************************************************************************
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64
#
#
#
# ****************************************************************************************************
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64
#
#
#
# ****************************************************************************************************
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64
#
#
#
# ****************************************************************************************************
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64
#
#
#
# ****************************************************************************************************
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64
#
#
#
# ****************************************************************************************************
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64
#
#
#
# ****************************************************************************************************
# 0      1094
# 1       483
# 2       327
# 3       244
# 4       207
#        ...
# 615       1
# 538       1
# 823       1
# 650       1
# 901       1
# Name: Votes, Length: 1012, dtype: int64
#
#
#
# ****************************************************************************************************
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
#
#
#
# ****************************************************************************************************

# %% [markdown]
# Here we can see the value count for each of the columns seperately present in the dataset.

# %%
df.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# 50%       2.000000          3.200000     31.000000
# 75%       2.000000          3.700000    131.000000
# max       4.000000          4.900000  10934.000000

# %% [markdown]
# # Observation

# %% [markdown]
# 1. count for each of the columns is same which means that there are no null values present in the dataset.
#
#
# 2. In columns "country code", "Average Cost for two", "Votes" mean is greater than median which means that skewness is present and data is skewed to the right in this columns.
#
#
# 3. In columns "Longitude", "Latitude", "price range", "Aggregate rating" mean is less than median which means that the data is skewed to the left in this columns.
#
#
# 4. There is a huge difference between 75th percentile and max values so we can say that outliers are present in the dataset.
#
#
# 5. We can also observe std., min., 25th, 50th, 75th, and max values for each of the columns

# %% [markdown]
# # Seprating categorical column & Numerical column

# %% [markdown]
# ## categorical columns

# %%
# Separating categorical columns
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['Restaurant Name', 'City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating color', 'Rating text', 'Country']

# %% [markdown]
# ## Numerical columns

# %%
# Separating numerical columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [markdown]
# These are the categorical and numerical columns present in the dataset.

# %% [markdown]
# # Now we will use group by feature to group the variables which are related to eachother.

# %%
df2 = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df2
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# 15               3.2       Orange     Average           522
# 16               3.3       Orange     Average           483
# 17               3.4       Orange     Average           498
# 18               3.5       Yellow        Good           480
# 19               3.6       Yellow        Good           458
# 20               3.7       Yellow        Good           427
# 21               3.8       Yellow        Good           400
# 22               3.9       Yellow        Good           335
# 23               4.0        Green   Very Good           266
# 24               4.1        Green   Very Good           274
# 25               4.2        Green   Very Good           221
# 26               4.3        Green   Very Good           174
# 27               4.4        Green   Very Good           144
# 28               4.5   Dark Green   Excellent            95
# 29               4.6   Dark Green   Excellent            78
# 30               4.7   Dark Green   Excellent            42
# 31               4.8   Dark Green   Excellent            25
# 32               4.9   Dark Green   Excellent            61

# %% [markdown]
# ## Observation

# %% [markdown]
# By grouping these variables we can understand the realation between Aggregate rating, color and text.
#
# We can say that the following color assigned to the ratings:
#
#
# Rating 0 - White - Not rated
#
#
# Rating 1.8 to 2.4 - Red - Poor
#
#
# Rating 2.5 to 3.4 - Orange - Average
#
#
# Rating 3.5 to 3.9 - Yellow - Good
#
#
# Rating 4.0 to 4.4 - Green - Very Good
#
#
# Rating 4.5 to 4.9 - Dark Green - Excellent

# %% [markdown]
# # Now we will check country with no rating

# %%
No_rating = df[df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# Here we can see that india has highest number of restaurents with no rating.

# %% [markdown]
# # Country with maximum rating

# %%
Max_rating = df[df['Rating color']=='Dark Green'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
Max_rating
# Out:
#            Country  Rating Count
# 0        Australia             1
# 1           Brazil            16
# 2            India           116
# 3        Indonesia             7
# 4      New Zealand            12
# 5      Phillipines            12
# 6            Qatar             4
# 7     South Africa            12
# 8        Sri Lanka             2
# 9           Turkey            10
# 10             UAE            18
# 11  United Kingdom            23
# 12   United States            68

# %% [markdown]
# We can observe that here india is also the country with the highest restaurents ratings.

# %% [markdown]
# By this we can conclude that india has highest number of restaurent listed on zomato.

# %% [markdown]
# # Now we group the country with their currency

# %%
country_currency = df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency.sort_values('Currency').reset_index(drop=True)
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2        Australia               Dollar($)
# 3           Canada               Dollar($)
# 4        Singapore               Dollar($)
# 5    United States               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(��)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %% [markdown]
# Here we can see the list of all the countries with their currency.

# %%
df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# India has highest number of count of restaurents.

# %%
df.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %% [markdown]
# New delhi has highest number of restaurent listed on zomato & vineland station has least number of restaurent listed on zomato.

# %% [markdown]
# # Lets list all the country now and do analysis

# %%
indiaRestro=df[df['Country']=='India']
singaporeRestro=df[df['Country']=='Singapore']
AusRestro=df[df['Country']=='Australia']
BrazRestro=df[df['Country']=='Brazil']
CanadaRestro=df[df['Country']=='Canada']
UAERestro=df[df['Country']=='UAE']
UKRestro=df[df['Country']=='United Kingdom']
USRestro=df[df['Country']=='United States']
SouthAfricaRestro=df[df['Country']=='South Africa']
NewZelandRestro=df[df['Country']=='New Zealand']
TurkeyRestro=df[df['Country']=='Turkey']
IndonesiaRestro=df[df['Country']=='Indonesia']
QatarRestro=df[df['Country']=='Qatar']
SrilankaRestro=df[df['Country']=='Sri Lanka']

# %%
indiaRestro.head(10)
# Out:
#                            Restaurant Name  Country Code  City  \
# 624                             Jahanpanah             1  Agra
# 625                    Rangrezz Restaurant             1  Agra
# 626                Time2Eat - Mama Chicken             1  Agra
# 627  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628                         Pinch Of Spice             1  Agra
# 629                              MoMo Cafe             1  Agra
# 630                  Peshawri - ITC Mughal             1  Agra
# 631                  Taj Bano - ITC Mughal             1  Agra
# 632                                 G Thal             1  Agra
# 633           Dawat-e-Nawab - Radisson Blu             1  Agra
#
#                                 Locality  \
# 624                           Agra Cantt
# 625                           Agra Cantt
# 626                           Agra Cantt
# 627                          Civil Lines
# 628                          Civil Lines
# 629  Courtyard by Marriott Agra, Tajganj
# 630                  ITC Mughal, Tajganj
# 631                  ITC Mughal, Tajganj
# 632                             Khandari
# 633                Radisson Blu, Tajganj
#
#                               Locality Verbose  Longitude   Latitude  \
# 624                           Agra Cantt, Agra  78.011544  27.161661
# 625                           Agra Cantt, Agra   0.000000   0.000000
# 626                           Agra Cantt, Agra  78.011608  27.160832
# 627                          Civil Lines, Agra  77.998092  27.195928
# 628                          Civil Lines, Agra  78.007553  27.201725
# 629  Courtyard by Marriott Agra, Tajganj, Agra   0.000000   0.000000
# 630                  ITC Mughal, Tajganj, Agra  78.044095  27.160934
# 631                  ITC Mughal, Tajganj, Agra  78.044095  27.160934
# 632                             Khandari, Agra   0.000000   0.000000
# 633                Radisson Blu, Tajganj, Agra  78.057044  27.163303
#
#                            Cuisines  Average Cost for two            Currency  \
# 624           North Indian, Mughlai                   850  Indian Rupees(Rs.)
# 625           North Indian, Mughlai                   700  Indian Rupees(Rs.)
# 626                    North Indian                   500  Indian Rupees(Rs.)
# 627                      Rajasthani                   400  Indian Rupees(Rs.)
# 628  North Indian, Chinese, Mughlai                  1000  Indian Rupees(Rs.)
# 629          North Indian, European                  2000  Indian Rupees(Rs.)
# 630           North Indian, Mughlai                  2500  Indian Rupees(Rs.)
# 631                         Mughlai                  2500  Indian Rupees(Rs.)
# 632   Rajasthani, Gujarati, Mughlai                   800  Indian Rupees(Rs.)
# 633           North Indian, Mughlai                  3600  Indian Rupees(Rs.)
#
#     Has Table booking Has Online delivery Is delivering now  Price range  \
# 624                No                  No                No            3
# 625                No                  No                No            2
# 626                No                  No                No            2
# 627                No                  No                No            2
# 628                No                  No                No            3
# 629                No                  No                No            4
# 630                No                  No                No            4
# 631                No                  No                No            4
# 632                No                  No                No            3
# 633                No                  No                No            4
#
#      Aggregate rating Rating color Rating text  Votes Country
# 624               3.9       Yellow        Good    140   India
# 625               3.5       Yellow        Good     71   India
# 626               3.6       Yellow        Good     94   India
# 627               4.0        Green   Very Good     87   India
# 628               4.2        Green   Very Good    177   India
# 629               4.0        Green   Very Good     45   India
# 630               4.3        Green   Very Good    133   India
# 631               4.0        Green   Very Good     41   India
# 632               3.6       Yellow        Good     59   India
# 633               3.8       Yellow        Good     46   India

# %% [markdown]
# We can see the list of india country restauarant listed on zomato

# %% [markdown]
# # Data visualization

# %%
print(indiaRestro.City.value_counts())
plt.figure(figsize=(10,10))
sns.countplot(indiaRestro['City'])
plt.xticks(rotation=90)
plt.show()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# Name: City, dtype: int64

# %% [markdown]
# In india New delhi has highest number of restaurant and mohali,Panchkula has least number of restaurant.

# %% [markdown]
# # Top restaurant in delhi based on the rating and vote count

# %%
DelhiTopRestro=indiaRestro[(indiaRestro['City']=='New Delhi')&(indiaRestro['Aggregate rating']>4.5)][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes')
DelhiTopRestro
# Out:
#       Aggregate rating            Restaurant Name  Votes
# 3013               4.9         Naturals Ice Cream   2620
# 3601               4.9  Indian Accent - The Manor   1934
# 6659               4.6   The California Boulevard   1691
# 4639               4.6                  Big Chill   1569
# 6997               4.7        Echoes Satyaniketan   1563
# 7849               4.6            Cafeteria & Co.   1136
# 3310               4.6              Spezia Bistro   1071
# 6657               4.7         Naturals Ice Cream    474
# 4298               4.9             Masala Library    408
# 3732               4.6                     Tashan    304
# 7067               4.7                   Pa Pa Ya    268
# 3014               4.7   Zabardast Indian Kitchen    242
# 6655               4.6         Band Baaja Baaraat    128
# 7180               4.6                Greenr Cafe    112
# 6656               4.8               Kopper Kadai     83
# 6426               4.6                Food Scouts     61
# 3012               4.7                MOB Brewpub     52

# %%
plt.figure(figsize=(10,10))
sns.countplot(DelhiTopRestro['Restaurant Name'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# On the basis of Aggregate rating and votes we can see that Naturals Ice Cream has highest rating among all the other restaurant and rest of the restaurant has similar ratings.

# %% [markdown]
# # New delhi top restaurant with online delivery

# %%
OnlineDelhitoprestro=indiaRestro[(indiaRestro['City']=='New Delhi')&(indiaRestro['Aggregate rating']>4.5) &(indiaRestro['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes','Has Online delivery']].sort_values(ascending=False,by='Votes')
OnlineDelhitoprestro
# Out:
#       Aggregate rating           Restaurant Name  Votes Has Online delivery
# 3013               4.9        Naturals Ice Cream   2620                 Yes
# 3310               4.6             Spezia Bistro   1071                 Yes
# 6657               4.7        Naturals Ice Cream    474                 Yes
# 3014               4.7  Zabardast Indian Kitchen    242                 Yes
# 7180               4.6               Greenr Cafe    112                 Yes
# 6426               4.6               Food Scouts     61                 Yes

# %% [markdown]
# Here we can see the list of restaurant with online delivery option

# %%
plt.figure(figsize=(10,10))
sns.factorplot('Restaurant Name',kind='count',data=OnlineDelhitoprestro,hue='Has Online delivery',palette="spring")
plt.xticks(rotation=90)
plt.show()

# %%
print(df['Price range'].value_counts())


plt.figure(figsize=(10,10))
sns.countplot(df['Price range'])
plt.show()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# We can see that price range 1 has maximum count

# %%
col1 = ['Has Table booking', 'Has Online delivery', 'Is delivering now','Price range', 'Rating color','Rating text']

# %%
 for i in col1:
        plt.figure(figsize=(10,5),facecolor='white')
        plt.pie(df[i].value_counts().values,labels=df[i].value_counts().index,autopct='%1.2f%%', shadow=True)
        plt.legend(prop={'size':10})
        plt.axis('equal')
        plt.tight_layout()
        plt.title(i)
        plt.show()
        print('\n\n')
        print ('*'*100)
# Out:
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************

# %% [markdown]
# ### Observations

# %% [markdown]
# 1. Online Delivery is very less in India.
#
#
# 2. Very less company are delivery now.
#
#
# 3. Maximum price range is 1.
#
#
# 4. Rating color Orange in maximum.
#
#
# 5. Rating Text is maximum Average.
#
#
# 6. Very less restaurant has online table booking option.

# %% [markdown]
# # Top cuisines in each region

# %%
IndianCuisines=df[df['Country']=='India']['Cuisines'].value_counts().head()
IndianCuisines
# Out:
# North Indian             936
# North Indian, Chinese    511
# Fast Food                348
# Chinese                  340
# North Indian, Mughlai    334
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(10,10))
indiaRestro['Cuisines'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %% [markdown]
# North Indian dishes are most in counts with 26.9% and the least is street food with 4.3%

# %% [markdown]
# ['Restaurant Name', 'City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']

# %% [markdown]
# ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
plt.figure(figsize=(10,10))
sns.lineplot(indiaRestro["Rating text"],indiaRestro["Average Cost for two"])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# Here we can see that Rating text has affecting the average cost for two If the rating text is "Excellent" the avg. cost for two is high and if there is no rating or "Average" rating in that case Average cost for two is very low.

# %%
print(df['Rating text'].unique())
print(df['Rating text'].nunique())
print(df['Rating text'].value_counts())
# Out:
# ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']
# 6
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
(df['Rating text'].value_counts()[:6]).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that maximum rating text is "Average" and minimum is "Poor"

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)
# Out:
# Restaurant Name
# Toit                               10934.0
# Hauz Khas Social                    7931.0
# Peter Cat                           7574.0
# Big Brewsky                         5705.0
# The Black Pearl                     5385.0
#                                     ...
# New Bhappe Di Hatti                    0.0
# New Aggarwal Sweets & Fast Food        0.0
# Nehra's Food Point                     0.0
# Negi Restaurant                        0.0
# Laxmi Food Corner                      0.0
# Name: Votes, Length: 7446, dtype: float64

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)[:10].plot(kind='bar', color='black', figsize=(10,8), title="Outlets Having Maximum Votes", xlabel='Top 10 Outlets', ylabel='Average votes')
# Out:
# <AxesSubplot:title={'center':'Outlets Having Maximum Votes'}, xlabel='Top 10 Outlets', ylabel='Average votes'>

# %% [markdown]
# # Multivarient Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Here we can see the pair plot of all the variables present in the dataset.

# %%
sns.pairplot(df, hue='Average Cost for two')
plt.show()

# %% [markdown]
# Here we can see the pair plot of all the different different variables present in the dataset with hue='Average Cost for two'

# %%
sns.pairplot(df, hue='Price range')
plt.show()

# %% [markdown]
# Here we can see the pair plot of all the different different variables present in the dataset with hue='Price range'

# %% [markdown]
# # Checking for outliers

# %%
for i in numerical_columns:
    df.boxplot(i)
    plt.show()

# %% [markdown]
# We never check prescence of outliers from categorical columns and target variables & to check the prescence of outliers we use boxplot visualization. Here by boxplot visualization we can say that outliers are present in the dataset. so we need to remove the outliers from the dataset.

# %% [markdown]
# # Removing Outliers

# %%
#Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df[numerical_columns]))

z
# Out:
#       Country Code  Longitude  Latitude  Average Cost for two  Price range  \
# 0         2.531111   1.372269  1.025581              0.006154     1.319803
# 1         2.531111   1.371945  1.026647              0.000049     1.319803
# 2         2.531111   1.372975  1.024131              0.173743     2.424090
# 3         2.531111   1.372966  1.023775              0.018659     2.424090
# 4         2.531111   1.372991  1.023854              0.018659     2.424090
# ...            ...        ...       ...                   ...          ...
# 9546      3.341718   0.847685  1.378025              0.069428     1.319803
# 9547      3.341718   0.846144  1.376849              0.067878     1.319803
# 9548      3.341718   0.846305  1.381025              0.063845     2.424090
# 9549      3.341718   0.846272  1.381221              0.066947     2.424090
# 9550      3.341718   0.846513  1.374571              0.070979     0.215516
#
#       Aggregate rating     Votes
# 0             1.407131  0.365202
# 1             1.209281  1.009168
# 2             1.143331  0.262911
# 3             1.473081  0.483766
# 4             1.407131  0.167595
# ...                ...       ...
# 9546          0.945480  1.467151
# 9547          1.011430  2.039049
# 9548          0.681680  1.171903
# 9549          0.879530  1.729853
# 9550          0.879530  1.009168
#
# [9551 rows x 7 columns]

# %%
#threshold value =3
threshold=3

print(np.where(z>3))
# Out:
# (array([  22,   23,   24, ..., 9548, 9549, 9550], dtype=int64), array([2, 2, 2, ..., 0, 0, 0], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

df_new
# Out:
#                                Restaurant Name  Country Code  \
# 0                             Le Petit Souffle           162
# 1                             Izakaya Kikufuji           162
# 2                       Heat - Edsa Shangri-La           162
# 3                                         Ooma           162
# 4                                  Sambo Kojin           162
# ...                                        ...           ...
# 9432                                   Eatopia           166
# 9433                      Vine - The St. Regis           166
# 9434  Sabai Thai - The Westin Doha Hotel & Spa           166
# 9435                                Paper Moon           166
# 9436                               Roti & Boti           166
#
#                   City                                         Locality  \
# 0          Makati City        Century City Mall, Poblacion, Makati City
# 1          Makati City       Little Tokyo, Legaspi Village, Makati City
# 2     Mandaluyong City       Edsa Shangri-La, Ortigas, Mandaluyong City
# 3     Mandaluyong City           SM Megamall, Ortigas, Mandaluyong City
# 4     Mandaluyong City           SM Megamall, Ortigas, Mandaluyong City
# ...                ...                                              ...
# 9432              Doha                                  The Gate, Dafna
# 9433              Doha                           The St. Regis, Westbay
# 9434              Doha  The Westin Doha Hotel & Spa, Fereej Bin Mahmoud
# 9435              Doha                                   Umm Ghuwailina
# 9436              Doha                                   Umm Ghuwailina
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9432                              The Gate, Dafna, Doha   51.526653
# 9433                       The St. Regis, Westbay, Doha   51.530127
# 9434  The Westin Doha Hotel & Spa, Fereej Bin Mahmou...   51.512909
# 9435                               Umm Ghuwailina, Doha   51.544576
# 9436                               Umm Ghuwailina, Doha   51.546714
#
#        Latitude                                       Cuisines  \
# 0     14.565443                     French, Japanese, Desserts
# 1     14.553708                                       Japanese
# 2     14.581404               Seafood, Asian, Filipino, Indian
# 3     14.585318                                Japanese, Sushi
# 4     14.584450                               Japanese, Korean
# ...         ...                                            ...
# 9432  25.323261  European, Arabian, Japanese, Bakery, Desserts
# 9433  25.350325                                  International
# 9434  25.276180                                           Thai
# 9435  25.273020                                        Italian
# 9436  25.283011                                         Indian
#
#       Average Cost for two          Currency Has Table booking  \
# 0                     1100  Botswana Pula(P)               Yes
# 1                     1200  Botswana Pula(P)               Yes
# 2                     4000  Botswana Pula(P)               Yes
# 3                     1500  Botswana Pula(P)                No
# 4                     1500  Botswana Pula(P)               Yes
# ...                    ...               ...               ...
# 9432                   200   Qatari Rial(QR)                No
# 9433                   550   Qatari Rial(QR)                No
# 9434                   445   Qatari Rial(QR)                No
# 9435                   400   Qatari Rial(QR)                No
# 9436                   160   Qatari Rial(QR)                No
#
#      Has Online delivery Is delivering now  Price range  Aggregate rating  \
# 0                     No                No            3               4.8
# 1                     No                No            3               4.5
# 2                     No                No            4               4.4
# 3                     No                No            4               4.9
# 4                     No                No            4               4.8
# ...                  ...               ...          ...               ...
# 9432                  No                No            4               3.9
# 9433                  No                No            4               4.4
# 9434                  No                No            4               4.3
# 9435                  No                No            4               4.5
# 9436                  No                No            4               3.9
#
#      Rating color Rating text  Votes      Country
# 0      Dark Green   Excellent    314  Phillipines
# 1      Dark Green   Excellent    591  Phillipines
# 2           Green   Very Good    270  Phillipines
# 3      Dark Green   Excellent    365  Phillipines
# 4      Dark Green   Excellent    229  Phillipines
# ...           ...         ...    ...          ...
# 9432       Yellow        Good    197        Qatar
# 9433        Green   Very Good     67        Qatar
# 9434        Green   Very Good     73        Qatar
# 9435   Dark Green   Excellent    145        Qatar
# 9436       Yellow        Good    109        Qatar
#
# [8565 rows x 19 columns]

# %%
df_new.shape
# Out:
# (8565, 19)

# %%
df.shape
# Out:
# (9551, 19)

# %%
DataLoss= ((9551-8565)/9551)*100
print("Data loss is ", DataLoss)
# Out:
# Data loss is  10.323526332321222

# %% [markdown]
# Here we can see that the dataloss percentage is approximately 10% which is in accpetable limit so we can further proceed with the dataset.

# %%
df=df_new

# %%
df.shape
# Out:
# (8565, 19)

# %% [markdown]
# # Check for skewness

# %%
df.skew()
# Out:
# Country Code            11.593933
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     3.718671
# Price range              1.029231
# Aggregate rating        -0.877262
# Votes                    3.653843
# dtype: float64

# %% [markdown]
# Accpetable range for skewness is -0.5 to +0.5 and according to this we can say that skewness is present in the dataset. we never remove skewness from target column and categorical columns.

# %% [markdown]
# Column ["country code", "Longitude", "Latitude", "Average cost for two","price range", "Aggrregate rating", "votes" ] have skewness

# %%
skew_col=['Country Code','Longitude','Latitude' ,'Price range','Aggregate rating','Votes']

# %%
# Lets remove the skewness from given columns by Power Transform Method

from sklearn.preprocessing import PowerTransformer
PT = PowerTransformer(method='yeo-johnson')

# %%
#Removing skewness using yeo-johnson
df[['Country Code','Longitude','Latitude' ,'Price range','Aggregate rating','Votes']] = PT.fit_transform(df[['Country Code','Longitude','Latitude' ,'Price range','Aggregate rating','Votes']].values)

# %%
df.skew()
# Out:
# Country Code            11.532839
# Longitude               -0.249360
# Latitude                -2.531937
# Average Cost for two     3.718671
# Price range              0.240185
# Aggregate rating        -0.631024
# Votes                   -0.008984
# dtype: float64

# %% [markdown]
# As we can see here that most of the skewness is removed from the dataset & we can't treat skewnes more further

# %%
for i in numerical_columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# After visualization with distplot we can see that skewnes is removed from the dataset "Average cost for two" is our target variable so we don't need to remove skewness from there

# %% [markdown]
# # Encoding the categorical columns using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Restaurant Name  Country Code  City  Locality  Locality Verbose  \
# 0                3321     11.616899    27        98                99
# 1                2794     11.616899    27       376               384
# 2                2550     11.616899    28       185               191
# 3                4150     11.616899    28       549               562
# 4                4878     11.616899    28       549               562
# ...               ...           ...   ...       ...               ...
# 9432             1947     11.616899    13       717               770
# 9433             6352     11.616899    13       736               789
# 9434             4824     11.616899    13       742               795
# 9435             4253     11.616899    13       759               814
# 9436             4767     11.616899    13       759               814
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# 0      7.096817 -2.870154       657                  1100         0
# 1      7.094048 -2.870996       783                  1200         0
# 2      7.102859 -2.869007      1271                  4000         0
# 3      7.102785 -2.868725       794                  1500         0
# 4      7.102998 -2.868788       793                  1500         0
# ...         ...       ...       ...                   ...       ...
# 9432  -2.075973 -0.937919       552                   200         4
# 9433  -2.075747 -0.929022       718                   550         4
# 9434  -2.076865 -0.953334      1364                   445         4
# 9435  -2.074809 -0.954365       719                   400         4
# 9436  -2.074670 -0.951102       715                   160         4
#
#       Has Table booking  Has Online delivery  Is delivering now  Price range  \
# 0                     1                    0                  0     1.385129
# 1                     1                    0                  0     1.385129
# 2                     1                    0                  0     1.744844
# 3                     0                    0                  0     1.744844
# 4                     1                    0                  0     1.744844
# ...                 ...                  ...                ...          ...
# 9432                  0                    0                  0     1.744844
# 9433                  0                    0                  0     1.744844
# 9434                  0                    0                  0     1.744844
# 9435                  0                    0                  0     1.744844
# 9436                  0                    0                  0     1.744844
#
#       Aggregate rating  Rating color  Rating text     Votes  Country
# 0             1.972392             0            1  1.410787        2
# 1             1.649065             0            1  1.753948        2
# 2             1.543945             1            5  1.329422        2
# 3             2.082799             0            1  1.492117        2
# 4             1.972392             0            1  1.240914        2
# ...                ...           ...          ...       ...      ...
# 9432          1.038603             5            2  1.160268        3
# 9433          1.543945             1            5  0.590036        3
# 9434          1.440165             1            5  0.634827        3
# 9435          1.649065             0            1  0.996808        3
# 9436          1.038603             5            2  0.845554        3
#
# [8565 rows x 19 columns]

# %%
df.head(5)
# Out:
#    Restaurant Name  Country Code  City  Locality  Locality Verbose  Longitude  \
# 0             3321     11.616899    27        98                99   7.096817
# 1             2794     11.616899    27       376               384   7.094048
# 2             2550     11.616899    28       185               191   7.102859
# 3             4150     11.616899    28       549               562   7.102785
# 4             4878     11.616899    28       549               562   7.102998
#
#    Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0 -2.870154       657                  1100         0                  1
# 1 -2.870996       783                  1200         0                  1
# 2 -2.869007      1271                  4000         0                  1
# 3 -2.868725       794                  1500         0                  0
# 4 -2.868788       793                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0                    0                  0     1.385129          1.972392
# 1                    0                  0     1.385129          1.649065
# 2                    0                  0     1.744844          1.543945
# 3                    0                  0     1.744844          2.082799
# 4                    0                  0     1.744844          1.972392
#
#    Rating color  Rating text     Votes  Country
# 0             0            1  1.410787        2
# 1             0            1  1.753948        2
# 2             1            5  1.329422        2
# 3             0            1  1.492117        2
# 4             0            1  1.240914        2

# %% [markdown]
# # Correlation between target variable and independent variables

# %%
cor=df.corr()
cor
# Out:
#                       Restaurant Name  Country Code      City  Locality  \
# Restaurant Name              1.000000      0.012685  0.008530  0.008658
# Country Code                 0.012685      1.000000  0.020689 -0.028893
# City                         0.008530      0.020689  1.000000 -0.029670
# Locality                     0.008658     -0.028893 -0.029670  1.000000
# Locality Verbose             0.008637     -0.028208 -0.033822  0.999002
# Longitude                    0.019722      0.292598  0.054221 -0.026209
# Latitude                     0.005493     -0.202920  0.081057  0.017092
# Cuisines                     0.060832     -0.020096  0.014873 -0.015087
# Average Cost for two         0.051725      0.010554 -0.059545 -0.041655
# Currency                     0.000797     -0.210036 -0.134651 -0.010129
# Has Table booking            0.041460      0.029633 -0.002165 -0.070155
# Has Online delivery          0.031504     -0.053197 -0.017478 -0.049229
# Is delivering now            0.013050     -0.005434 -0.023878 -0.011218
# Price range                  0.064012      0.134602 -0.119901 -0.101930
# Aggregate rating             0.028976      0.103545 -0.109620 -0.155147
# Rating color                -0.007253     -0.069728  0.067731  0.006835
# Rating text                  0.007538      0.037943 -0.055647 -0.000465
# Votes                        0.038778      0.075480 -0.097033 -0.178258
# Country                      0.007505      0.960105  0.030770 -0.031437
#
#                       Locality Verbose  Longitude  Latitude  Cuisines  \
# Restaurant Name               0.008637   0.019722  0.005493  0.060832
# Country Code                 -0.028208   0.292598 -0.202920 -0.020096
# City                         -0.033822   0.054221  0.081057  0.014873
# Locality                      0.999002  -0.026209  0.017092 -0.015087
# Locality Verbose              1.000000  -0.027072  0.016162 -0.016232
# Longitude                    -0.027072   1.000000  0.579900  0.004392
# Latitude                      0.016162   0.579900  1.000000  0.038402
# Cuisines                     -0.016232   0.004392  0.038402  1.000000
# Average Cost for two         -0.038586   0.073071 -0.012364  0.006327
# Currency                     -0.008717  -0.354945  0.116663  0.029270
# Has Table booking            -0.069131   0.079615  0.050272  0.039859
# Has Online delivery          -0.049567   0.105109  0.160799 -0.039823
# Is delivering now            -0.011166   0.011096  0.022612  0.005151
# Price range                  -0.099217   0.075264 -0.112352  0.027467
# Aggregate rating             -0.153900   0.175121 -0.027884 -0.056096
# Rating color                  0.007440  -0.104827 -0.006377 -0.047689
# Rating text                   0.001245  -0.077165 -0.185071 -0.061127
# Votes                        -0.176254   0.186750 -0.018102 -0.029703
# Country                      -0.030599   0.232608 -0.196182 -0.021027
#
#                       Average Cost for two  Currency  Has Table booking  \
# Restaurant Name                   0.051725  0.000797           0.041460
# Country Code                      0.010554 -0.210036           0.029633
# City                             -0.059545 -0.134651          -0.002165
# Locality                         -0.041655 -0.010129          -0.070155
# Locality Verbose                 -0.038586 -0.008717          -0.069131
# Longitude                         0.073071 -0.354945           0.079615
# Latitude                         -0.012364  0.116663           0.050272
# Cuisines                          0.006327  0.029270           0.039859
# Average Cost for two              1.000000 -0.067872           0.617051
# Currency                         -0.067872  1.000000          -0.055098
# Has Table booking                 0.617051 -0.055098           1.000000
# Has Online delivery               0.062763  0.011173           0.078618
# Is delivering now                 0.009316  0.001141          -0.018177
# Price range                       0.699506 -0.025634           0.496771
# Aggregate rating                  0.350264 -0.028879           0.228460
# Rating color                     -0.033294  0.042093          -0.022315
# Rating text                       0.095707 -0.000150           0.049391
# Votes                             0.424192 -0.022035           0.313240
# Country                          -0.012355 -0.139876           0.010793
#
#                       Has Online delivery  Is delivering now  Price range  \
# Restaurant Name                  0.031504           0.013050     0.064012
# Country Code                    -0.053197          -0.005434     0.134602
# City                            -0.017478          -0.023878    -0.119901
# Locality                        -0.049229          -0.011218    -0.101930
# Locality Verbose                -0.049567          -0.011166    -0.099217
# Longitude                        0.105109           0.011096     0.075264
# Latitude                         0.160799           0.022612    -0.112352
# Cuisines                        -0.039823           0.005151     0.027467
# Average Cost for two             0.062763           0.009316     0.699506
# Currency                         0.011173           0.001141    -0.025634
# Has Table booking                0.078618          -0.018177     0.496771
# Has Online delivery              1.000000           0.102157     0.203256
# Is delivering now                0.102157           1.000000     0.030144
# Price range                      0.203256           0.030144     1.000000
# Aggregate rating                 0.283388           0.024494     0.429224
# Rating color                    -0.019556          -0.002842    -0.073294
# Rating text                     -0.058468          -0.029627     0.062516
# Votes                            0.369929           0.034700     0.523711
# Country                         -0.051074          -0.005218     0.130354
#
#                       Aggregate rating  Rating color  Rating text     Votes  \
# Restaurant Name               0.028976     -0.007253     0.007538  0.038778
# Country Code                  0.103545     -0.069728     0.037943  0.075480
# City                         -0.109620      0.067731    -0.055647 -0.097033
# Locality                     -0.155147      0.006835    -0.000465 -0.178258
# Locality Verbose             -0.153900      0.007440     0.001245 -0.176254
# Longitude                     0.175121     -0.104827    -0.077165  0.186750
# Latitude                     -0.027884     -0.006377    -0.185071 -0.018102
# Cuisines                     -0.056096     -0.047689    -0.061127 -0.029703
# Average Cost for two          0.350264     -0.033294     0.095707  0.424192
# Currency                     -0.028879      0.042093    -0.000150 -0.022035
# Has Table booking             0.228460     -0.022315     0.049391  0.313240
# Has Online delivery           0.283388     -0.019556    -0.058468  0.369929
# Is delivering now             0.024494     -0.002842    -0.029627  0.034700
# Price range                   0.429224     -0.073294     0.062516  0.523711
# Aggregate rating              1.000000     -0.298292    -0.234622  0.857656
# Rating color                 -0.298292      1.000000     0.325392 -0.152206
# Rating text                  -0.234622      0.325392     1.000000 -0.069348
# Votes                         0.857656     -0.152206    -0.069348  1.000000
# Country                       0.091196     -0.049996     0.028502  0.061635
#
#                        Country
# Restaurant Name       0.007505
# Country Code          0.960105
# City                  0.030770
# Locality             -0.031437
# Locality Verbose     -0.030599
# Longitude             0.232608
# Latitude             -0.196182
# Cuisines             -0.021027
# Average Cost for two -0.012355
# Currency             -0.139876
# Has Table booking     0.010793
# Has Online delivery  -0.051074
# Is delivering now    -0.005218
# Price range           0.130354
# Aggregate rating      0.091196
# Rating color         -0.049996
# Rating text           0.028502
# Votes                 0.061635
# Country               1.000000

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(25,15))
sns.heatmap(df_new.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="ocean")
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5]),
#  [Text(0, 0.5, 'Restaurant Name'),
#   Text(0, 1.5, 'Country Code'),
#   Text(0, 2.5, 'City'),
#   Text(0, 3.5, 'Locality'),
#   Text(0, 4.5, 'Locality Verbose'),
#   Text(0, 5.5, 'Longitude'),
#   Text(0, 6.5, 'Latitude'),
#   Text(0, 7.5, 'Cuisines'),
#   Text(0, 8.5, 'Average Cost for two'),
#   Text(0, 9.5, 'Currency'),
#   Text(0, 10.5, 'Has Table booking'),
#   Text(0, 11.5, 'Has Online delivery'),
#   Text(0, 12.5, 'Is delivering now'),
#   Text(0, 13.5, 'Price range'),
#   Text(0, 14.5, 'Aggregate rating'),
#   Text(0, 15.5, 'Rating color'),
#   Text(0, 16.5, 'Rating text'),
#   Text(0, 17.5, 'Votes'),
#   Text(0, 18.5, 'Country')])

# %% [markdown]
# This heatmap shows the correlation matrix by visualizing the data. we can observe the relation between feature to feature and feature to label. This heat mapcontains both positive and negative correlation

# %%
cor['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.699506
# Has Table booking       0.617051
# Votes                   0.424192
# Aggregate rating        0.350264
# Rating text             0.095707
# Longitude               0.073071
# Has Online delivery     0.062763
# Restaurant Name         0.051725
# Country Code            0.010554
# Is delivering now       0.009316
# Cuisines                0.006327
# Country                -0.012355
# Latitude               -0.012364
# Rating color           -0.033294
# Locality Verbose       -0.038586
# Locality               -0.041655
# City                   -0.059545
# Currency               -0.067872
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# We can clearly see that Average cost for two is highly corelated with price range, has table booking columns.

# %% [markdown]
# # Visualizing the correlation between label and features

# %%
plt.figure(figsize=(20,10))
df_new.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can see the least correlated columns are "Is delivering now" and "Country code" and the max postive and Negative correlated columns as Price Range and Currency.

# %% [markdown]
# # Seprating features and label

# %%
x = df.drop("Average Cost for two", axis=1)
y = df["Average Cost for two"]

# %%
x.shape
# Out:
# (8565, 18)

# %%
y.shape
# Out:
# (8565,)

# %%
x
# Out:
#       Restaurant Name  Country Code  City  Locality  Locality Verbose  \
# 0                3321     11.616899    27        98                99
# 1                2794     11.616899    27       376               384
# 2                2550     11.616899    28       185               191
# 3                4150     11.616899    28       549               562
# 4                4878     11.616899    28       549               562
# ...               ...           ...   ...       ...               ...
# 9432             1947     11.616899    13       717               770
# 9433             6352     11.616899    13       736               789
# 9434             4824     11.616899    13       742               795
# 9435             4253     11.616899    13       759               814
# 9436             4767     11.616899    13       759               814
#
#       Longitude  Latitude  Cuisines  Currency  Has Table booking  \
# 0      7.096817 -2.870154       657         0                  1
# 1      7.094048 -2.870996       783         0                  1
# 2      7.102859 -2.869007      1271         0                  1
# 3      7.102785 -2.868725       794         0                  0
# 4      7.102998 -2.868788       793         0                  1
# ...         ...       ...       ...       ...                ...
# 9432  -2.075973 -0.937919       552         4                  0
# 9433  -2.075747 -0.929022       718         4                  0
# 9434  -2.076865 -0.953334      1364         4                  0
# 9435  -2.074809 -0.954365       719         4                  0
# 9436  -2.074670 -0.951102       715         4                  0
#
#       Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0                       0                  0     1.385129          1.972392
# 1                       0                  0     1.385129          1.649065
# 2                       0                  0     1.744844          1.543945
# 3                       0                  0     1.744844          2.082799
# 4                       0                  0     1.744844          1.972392
# ...                   ...                ...          ...               ...
# 9432                    0                  0     1.744844          1.038603
# 9433                    0                  0     1.744844          1.543945
# 9434                    0                  0     1.744844          1.440165
# 9435                    0                  0     1.744844          1.649065
# 9436                    0                  0     1.744844          1.038603
#
#       Rating color  Rating text     Votes  Country
# 0                0            1  1.410787        2
# 1                0            1  1.753948        2
# 2                1            5  1.329422        2
# 3                0            1  1.492117        2
# 4                0            1  1.240914        2
# ...            ...          ...       ...      ...
# 9432             5            2  1.160268        3
# 9433             1            5  0.590036        3
# 9434             1            5  0.634827        3
# 9435             0            1  0.996808        3
# 9436             5            2  0.845554        3
#
# [8565 rows x 18 columns]

# %%
y
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9432     200
# 9433     550
# 9434     445
# 9435     400
# 9436     160
# Name: Average Cost for two, Length: 8565, dtype: int64

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Restaurant Name  Country Code      City  Locality  Locality Verbose  \
# 0            0.052689     11.616901 -0.498280 -1.603037         -1.570067
# 1           -0.226145     11.616901 -0.498280 -0.280920         -0.312136
# 2           -0.355245     11.616901 -0.381656 -1.189281         -1.163998
# 3            0.491312     11.616901 -0.381656  0.541836          0.473520
# 4            0.876496     11.616901 -0.381656  0.541836          0.473520
# ...               ...           ...       ...       ...               ...
# 8560        -0.674292     11.616901 -2.131029  1.340813          1.391589
# 8561         1.656387     11.616901 -2.131029  1.431174          1.475451
# 8562         0.847925     11.616901 -2.131029  1.459708          1.501934
# 8563         0.545809     11.616901 -2.131029  1.540557          1.585796
# 8564         0.817766     11.616901 -2.131029  1.540557          1.585796
#
#       Longitude  Latitude  Cuisines   Currency  Has Table booking  \
# 0      7.096817 -2.870154 -0.166259 -13.447769           2.652303
# 1      7.094048 -2.870996  0.148814 -13.447769           2.652303
# 2      7.102859 -2.869007  1.369094 -13.447769           2.652303
# 3      7.102785 -2.868725  0.176320 -13.447769          -0.377031
# 4      7.102998 -2.868788  0.173820 -13.447769           2.652303
# ...         ...       ...       ...        ...                ...
# 8560  -2.075973 -0.937919 -0.428819  13.483930          -0.377031
# 8561  -2.075747 -0.929022 -0.013724  13.483930          -0.377031
# 8562  -2.076865 -0.953334  1.601647  13.483930          -0.377031
# 8563  -2.074809 -0.954365 -0.011223  13.483930          -0.377031
# 8564  -2.074670 -0.951102 -0.021225  13.483930          -0.377031
#
#       Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# 0               -0.617978          -0.063131     1.385129          1.972392
# 1               -0.617978          -0.063131     1.385129          1.649065
# 2               -0.617978          -0.063131     1.744844          1.543945
# 3               -0.617978          -0.063131     1.744844          2.082799
# 4               -0.617978          -0.063131     1.744844          1.972392
# ...                   ...                ...          ...               ...
# 8560            -0.617978          -0.063131     1.744844          1.038603
# 8561            -0.617978          -0.063131     1.744844          1.543945
# 8562            -0.617978          -0.063131     1.744844          1.440165
# 8563            -0.617978          -0.063131     1.744844          1.649065
# 8564            -0.617978          -0.063131     1.744844          1.038603
#
#       Rating color  Rating text     Votes    Country
# 0        -2.203028    -0.396310  1.410787   7.570045
# 1        -2.203028    -0.396310  1.753948   7.570045
# 2        -1.483690     2.085425  1.329422   7.570045
# 3        -2.203028    -0.396310  1.492117   7.570045
# 4        -2.203028    -0.396310  1.240914   7.570045
# ...            ...          ...       ...        ...
# 8560      1.393658     0.224124  1.160268  11.396391
# 8561     -1.483690     2.085425  0.590036  11.396391
# 8562     -1.483690     2.085425  0.634827  11.396391
# 8563     -2.203028    -0.396310  0.996808  11.396391
# 8564      1.393658     0.224124  0.845554  11.396391
#
# [8565 rows x 18 columns]

# %% [markdown]
# We have scaled the data using standard scalarization method to overcome the issue of biasness we have use standard scaler which will convert dataset into mean=0 and std=1
#
# Now we check for the multicolinearity for this we use Variance Inflation factor(VIF) method

# %% [markdown]
# # Checking for multicolinearity

# %%
# Find Varience Inflation Factor (VIF) in each scaled column above.

from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd


vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(x.values, i)
              for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF values             Features
# 0     1.009484      Restaurant Name
# 1    15.328947         Country Code
# 2     1.079190                 City
# 3   509.013686             Locality
# 4   508.775821     Locality Verbose
# 5     3.142886            Longitude
# 6     2.808150             Latitude
# 7     1.028686             Cuisines
# 8     1.525430             Currency
# 9     1.403791    Has Table booking
# 10    1.240679  Has Online delivery
# 11    1.013745    Is delivering now
# 12    1.770447          Price range
# 13    4.712460     Aggregate rating
# 14    1.242508         Rating color
# 15    1.307479          Rating text
# 16    5.045765                Votes
# 17   14.005991              Country

# %% [markdown]
# Accpetable range for vif value is within 10 if the vif value is greater than 10 then we can say that multicolinearity is present in the dataset here column "Locality", "Locality verbose", "country code", "country" columns have vif value greater than 10 so multicolinearity is present in the dataset to remove this multicolinearity we will remove the column with highest vif value from the dataset and than again check for the vif value till the vif value comes within the accpetable range.

# %%
x.drop("Locality",axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd


vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(x.values, i)
              for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF values             Features
# 0     1.009482      Restaurant Name
# 1    15.328789         Country Code
# 2     1.072195                 City
# 3     1.038196     Locality Verbose
# 4     3.141744            Longitude
# 5     2.807537             Latitude
# 6     1.028084             Cuisines
# 7     1.525313             Currency
# 8     1.403751    Has Table booking
# 9     1.239733  Has Online delivery
# 10    1.013745    Is delivering now
# 11    1.768537          Price range
# 12    4.711523     Aggregate rating
# 13    1.242385         Rating color
# 14    1.306933          Rating text
# 15    5.041283                Votes
# 16   14.004431              Country

# %%
x.drop("Country",axis=1,inplace=True)

# %%
vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(x.values, i)
              for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF values             Features
# 0     1.009232      Restaurant Name
# 1     1.459630         Country Code
# 2     1.068001                 City
# 3     1.038005     Locality Verbose
# 4     3.077912            Longitude
# 5     2.783937             Latitude
# 6     1.027961             Cuisines
# 7     1.501158             Currency
# 8     1.396337    Has Table booking
# 9     1.239732  Has Online delivery
# 10    1.013735    Is delivering now
# 11    1.760890          Price range
# 12    4.710443     Aggregate rating
# 13    1.239151         Rating color
# 14    1.305556          Rating text
# 15    5.040172                Votes

# %% [markdown]
# As we can clearly see here that multicolinearity is completely removed from the dataset. Now we can further process with the data.

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from math import sqrt

# %% [markdown]
# # Linear Regression

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print (f"At random state {i},the training accuracy is :- {r2_score(y_train,pred_train)}")
    print (f"At random state {i},the testing accuracy is :- {r2_score(y_test,pred_test)}")
    print ("\n\n")
# Out:
# At random state 0,the training accuracy is :- 0.612885746673909
# At random state 0,the testing accuracy is :- 0.6259741270960363
#
#
#
# At random state 1,the training accuracy is :- 0.6092895803280141
# At random state 1,the testing accuracy is :- 0.6444662217112194
#
#
#
# At random state 2,the training accuracy is :- 0.6089136727738187
# At random state 2,the testing accuracy is :- 0.6397907243193317
#
#
#
# At random state 3,the training accuracy is :- 0.6073973062791612
# At random state 3,the testing accuracy is :- 0.6521832544480668
#
#
#
# At random state 4,the training accuracy is :- 0.6163893838967951
# At random state 4,the testing accuracy is :- 0.6107065612041316
#
#
#
# At random state 5,the training accuracy is :- 0.6205247161559333
# At random state 5,the testing accuracy is :- 0.5977516847469393
#
#
#
# At random state 6,the training accuracy is :- 0.6084066832365873
# At random state 6,the testing accuracy is :- 0.646621917500745
#
#
#
# At random state 7,the training accuracy is :- 0.6108775234505168
# At random state 7,the testing accuracy is :- 0.6324531988926296
#
#
#
# At random state 8,the training accuracy is :- 0.6318018459919801
# At random state 8,the testing accuracy is :- 0.5657032297311746
#
#
#
# At random state 9,the training accuracy is :- 0.6290886094425453
# At random state 9,the testing accuracy is :- 0.568426289050869
#
#
#
# At random state 10,the training accuracy is :- 0.6183269460698844
# At random state 10,the testing accuracy is :- 0.6037663046683432
#
#
#
# At random state 11,the training accuracy is :- 0.613846781335962
# At random state 11,the testing accuracy is :- 0.622406045071708
#
#
#
# At random state 12,the training accuracy is :- 0.6211323642318094
# At random state 12,the testing accuracy is :- 0.5956016143553615
#
#
#
# At random state 13,the training accuracy is :- 0.6186608552866357
# At random state 13,the testing accuracy is :- 0.6029496546958806
#
#
#
# At random state 14,the training accuracy is :- 0.6072433790451957
# At random state 14,the testing accuracy is :- 0.6500009903514383
#
#
#
# At random state 15,the training accuracy is :- 0.60709685095469
# At random state 15,the testing accuracy is :- 0.6519134909038311
#
#
#
# At random state 16,the training accuracy is :- 0.6254944462321408
# At random state 16,the testing accuracy is :- 0.5811027033547219
#
#
#
# At random state 17,the training accuracy is :- 0.6117413264391596
# At random state 17,the testing accuracy is :- 0.629776710173316
#
#
#
# At random state 18,the training accuracy is :- 0.6170220928208738
# At random state 18,the testing accuracy is :- 0.6074182215946107
#
#
#
# At random state 19,the training accuracy is :- 0.6263191111293482
# At random state 19,the testing accuracy is :- 0.5810328578550188
#
#
#
# At random state 20,the training accuracy is :- 0.6121308152670082
# At random state 20,the testing accuracy is :- 0.62538446579788
#
#
#
# At random state 21,the training accuracy is :- 0.6154533805011165
# At random state 21,the testing accuracy is :- 0.615278446577716
#
#
#
# At random state 22,the training accuracy is :- 0.6433892494441973
# At random state 22,the testing accuracy is :- 0.5353773266687613
#
#
#
# At random state 23,the training accuracy is :- 0.6116829476619308
# At random state 23,the testing accuracy is :- 0.6302735357447422
#
#
#
# At random state 24,the training accuracy is :- 0.6179387283856985
# At random state 24,the testing accuracy is :- 0.6048197584388251
#
#
#
# At random state 25,the training accuracy is :- 0.6130986897931072
# At random state 25,the testing accuracy is :- 0.6248084687749779
#
#
#
# At random state 26,the training accuracy is :- 0.6284139255139287
# At random state 26,the testing accuracy is :- 0.5723366789954649
#
#
#
# At random state 27,the training accuracy is :- 0.6101512490914442
# At random state 27,the testing accuracy is :- 0.6386741320431739
#
#
#
# At random state 28,the training accuracy is :- 0.6130613656490662
# At random state 28,the testing accuracy is :- 0.6264689286946263
#
#
#
# At random state 29,the training accuracy is :- 0.6123526254446887
# At random state 29,the testing accuracy is :- 0.6268621771241554
#
#
#
# At random state 30,the training accuracy is :- 0.6163223434023939
# At random state 30,the testing accuracy is :- 0.61210413292999
#
#
#
# At random state 31,the training accuracy is :- 0.6121320949945592
# At random state 31,the testing accuracy is :- 0.627424873414521
#
#
#
# At random state 32,the training accuracy is :- 0.6220869636670232
# At random state 32,the testing accuracy is :- 0.5911941262723458
#
#
#
# At random state 33,the training accuracy is :- 0.6131287233668372
# At random state 33,the testing accuracy is :- 0.6226921206601718
#
#
#
# At random state 34,the training accuracy is :- 0.6204751412464382
# At random state 34,the testing accuracy is :- 0.5938442606804668
#
#
#
# At random state 35,the training accuracy is :- 0.6142221386307414
# At random state 35,the testing accuracy is :- 0.6209705836366372
#
#
#
# At random state 36,the training accuracy is :- 0.6148083584334904
# At random state 36,the testing accuracy is :- 0.6180163123015786
#
#
#
# At random state 37,the training accuracy is :- 0.6163724951394856
# At random state 37,the testing accuracy is :- 0.6096951539592077
#
#
#
# At random state 38,the training accuracy is :- 0.6164577468370156
# At random state 38,the testing accuracy is :- 0.6115369576193185
#
#
#
# At random state 39,the training accuracy is :- 0.6194419805755035
# At random state 39,the testing accuracy is :- 0.5973713351230867
#
#
#
# At random state 40,the training accuracy is :- 0.61339455390223
# At random state 40,the testing accuracy is :- 0.624185958183976
#
#
#
# At random state 41,the training accuracy is :- 0.6112096544796438
# At random state 41,the testing accuracy is :- 0.6345022498915237
#
#
#
# At random state 42,the training accuracy is :- 0.6158628450158006
# At random state 42,the testing accuracy is :- 0.6129578406589
#
#
#
# At random state 43,the training accuracy is :- 0.6082666126075751
# At random state 43,the testing accuracy is :- 0.6511862612950747
#
#
#
# At random state 44,the training accuracy is :- 0.6230628631174052
# At random state 44,the testing accuracy is :- 0.5873905683207872
#
#
#
# At random state 45,the training accuracy is :- 0.610988513030159
# At random state 45,the testing accuracy is :- 0.6326524456119045
#
#
#
# At random state 46,the training accuracy is :- 0.6156163845054423
# At random state 46,the testing accuracy is :- 0.6145173795570487
#
#
#
# At random state 47,the training accuracy is :- 0.613797783997041
# At random state 47,the testing accuracy is :- 0.6202054373767463
#
#
#
# At random state 48,the training accuracy is :- 0.6041649546952628
# At random state 48,the testing accuracy is :- 0.6637466140751405
#
#
#
# At random state 49,the training accuracy is :- 0.6130341002631701
# At random state 49,the testing accuracy is :- 0.6222759593622739
#
#
#
# At random state 50,the training accuracy is :- 0.6067021707574065
# At random state 50,the testing accuracy is :- 0.6570844782151926
#
#
#
# At random state 51,the training accuracy is :- 0.6116929522636714
# At random state 51,the testing accuracy is :- 0.6320190351334078
#
#
#
# At random state 52,the training accuracy is :- 0.6154513086216109
# At random state 52,the testing accuracy is :- 0.6142463584551829
#
#
#
# At random state 53,the training accuracy is :- 0.6102274864541055
# At random state 53,the testing accuracy is :- 0.6413542626462768
#
#
#
# At random state 54,the training accuracy is :- 0.622968318492894
# At random state 54,the testing accuracy is :- 0.5896824608569022
#
#
#
# At random state 55,the training accuracy is :- 0.6171575861200054
# At random state 55,the testing accuracy is :- 0.6084209964040195
#
#
#
# At random state 56,the training accuracy is :- 0.6194730096687082
# At random state 56,the testing accuracy is :- 0.598188780213536
#
#
#
# At random state 57,the training accuracy is :- 0.61809662695491
# At random state 57,the testing accuracy is :- 0.602901456436725
#
#
#
# At random state 58,the training accuracy is :- 0.613795501773609
# At random state 58,the testing accuracy is :- 0.620698956624461
#
#
#
# At random state 59,the training accuracy is :- 0.6262893234711153
# At random state 59,the testing accuracy is :- 0.5719011340097732
#
#
#
# At random state 60,the training accuracy is :- 0.6143473356829102
# At random state 60,the testing accuracy is :- 0.6194081787202625
#
#
#
# At random state 61,the training accuracy is :- 0.611838491303101
# At random state 61,the testing accuracy is :- 0.6290628303062933
#
#
#
# At random state 62,the training accuracy is :- 0.6210759481148489
# At random state 62,the testing accuracy is :- 0.5888888954709409
#
#
#
# At random state 63,the training accuracy is :- 0.6074325371655328
# At random state 63,the testing accuracy is :- 0.6481679514887342
#
#
#
# At random state 64,the training accuracy is :- 0.6121810024169985
# At random state 64,the testing accuracy is :- 0.6296407774523312
#
#
#
# At random state 65,the training accuracy is :- 0.6191920596126335
# At random state 65,the testing accuracy is :- 0.6005664900836405
#
#
#
# At random state 66,the training accuracy is :- 0.6222284781280093
# At random state 66,the testing accuracy is :- 0.5918973511964993
#
#
#
# At random state 67,the training accuracy is :- 0.6134900702391796
# At random state 67,the testing accuracy is :- 0.6231659344310883
#
#
#
# At random state 68,the training accuracy is :- 0.6238918063314218
# At random state 68,the testing accuracy is :- 0.5722184261024053
#
#
#
# At random state 69,the training accuracy is :- 0.6240034932182982
# At random state 69,the testing accuracy is :- 0.5801533263007767
#
#
#
# At random state 70,the training accuracy is :- 0.6166124481092619
# At random state 70,the testing accuracy is :- 0.6067139412055664
#
#
#
# At random state 71,the training accuracy is :- 0.623213994070796
# At random state 71,the testing accuracy is :- 0.585640727463278
#
#
#
# At random state 72,the training accuracy is :- 0.6188093859539492
# At random state 72,the testing accuracy is :- 0.6005415845990396
#
#
#
# At random state 73,the training accuracy is :- 0.6214656216874797
# At random state 73,the testing accuracy is :- 0.5935948881099743
#
#
#
# At random state 74,the training accuracy is :- 0.6062289180438292
# At random state 74,the testing accuracy is :- 0.6604636906609703
#
#
#
# At random state 75,the training accuracy is :- 0.6285772089124266
# At random state 75,the testing accuracy is :- 0.571797984287473
#
#
#
# At random state 76,the training accuracy is :- 0.6182086715169869
# At random state 76,the testing accuracy is :- 0.6052895907304312
#
#
#
# At random state 77,the training accuracy is :- 0.6115872090754298
# At random state 77,the testing accuracy is :- 0.6306944862036317
#
#
#
# At random state 78,the training accuracy is :- 0.6233972290474669
# At random state 78,the testing accuracy is :- 0.5863153422543256
#
#
#
# At random state 79,the training accuracy is :- 0.6310865965904264
# At random state 79,the testing accuracy is :- 0.5619408171095513
#
#
#
# At random state 80,the training accuracy is :- 0.6200268496976458
# At random state 80,the testing accuracy is :- 0.5986528118413037
#
#
#
# At random state 81,the training accuracy is :- 0.622764687912826
# At random state 81,the testing accuracy is :- 0.5870533637626052
#
#
#
# At random state 82,the training accuracy is :- 0.6110505353493865
# At random state 82,the testing accuracy is :- 0.6325517340388376
#
#
#
# At random state 83,the training accuracy is :- 0.6150115669450551
# At random state 83,the testing accuracy is :- 0.6169770142149494
#
#
#
# At random state 84,the training accuracy is :- 0.6165546154055754
# At random state 84,the testing accuracy is :- 0.611167049060815
#
#
#
# At random state 85,the training accuracy is :- 0.6118015927140413
# At random state 85,the testing accuracy is :- 0.6305198081670533
#
#
#
# At random state 86,the training accuracy is :- 0.606667793465518
# At random state 86,the testing accuracy is :- 0.6552036011200446
#
#
#
# At random state 87,the training accuracy is :- 0.6101947803738597
# At random state 87,the testing accuracy is :- 0.6363973254741294
#
#
#
# At random state 88,the training accuracy is :- 0.6100112123135815
# At random state 88,the testing accuracy is :- 0.6402222170925272
#
#
#
# At random state 89,the training accuracy is :- 0.6216640022403677
# At random state 89,the testing accuracy is :- 0.5920342754951633
#
#
#
# At random state 90,the training accuracy is :- 0.6225181177063195
# At random state 90,the testing accuracy is :- 0.5893484435972832
#
#
#
# At random state 91,the training accuracy is :- 0.6227992934951152
# At random state 91,the testing accuracy is :- 0.5897341523044582
#
#
#
# At random state 92,the training accuracy is :- 0.6164045477041329
# At random state 92,the testing accuracy is :- 0.6109689531554447
#
#
#
# At random state 93,the training accuracy is :- 0.61057621865266
# At random state 93,the testing accuracy is :- 0.6399381622388098
#
#
#
# At random state 94,the training accuracy is :- 0.608155439179414
# At random state 94,the testing accuracy is :- 0.654283167495235
#
#
#
# At random state 95,the training accuracy is :- 0.6166733558162809
# At random state 95,the testing accuracy is :- 0.6079654163882817
#
#
#
# At random state 96,the training accuracy is :- 0.6018733477645927
# At random state 96,the testing accuracy is :- 0.6796658898467258
#
#
#
# At random state 97,the training accuracy is :- 0.6264685534594668
# At random state 97,the testing accuracy is :- 0.5796681125137157
#
#
#
# At random state 98,the training accuracy is :- 0.6228325799215846
# At random state 98,the testing accuracy is :- 0.58374329754529
#
#
#
# At random state 99,the training accuracy is :- 0.6155446316641296
# At random state 99,the testing accuracy is :- 0.6141012728131796

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=21)

# %%
# train the model
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
accuracy_score=r2_score(y_test,pred_test)
print(accuracy_score)
# Out:
# 0.615278446577716

# %% [markdown]
# # Cross validation score

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,pred_lr)

# %%
for i in range(4,10):
    lsscore=cross_val_score(lr,x,y,cv=i)
    lsc=lsscore.mean()
    print ("At cv:-",i)
    print ("Cross validation score is :-",lsc*100)
    print ("Accuracy_score is :-",lss*100)
    print ("\n")
# Out:
# At cv:- 4
# Cross validation score is :- 40.42198751733842
# Accuracy_score is :- 61.5278446577716
#
#
# At cv:- 5
# Cross validation score is :- 36.3527426725296
# Accuracy_score is :- 61.5278446577716
#
#
# At cv:- 6
# Cross validation score is :- 29.733004188145912
# Accuracy_score is :- 61.5278446577716
#
#
# At cv:- 7
# Cross validation score is :- 30.901687966099683
# Accuracy_score is :- 61.5278446577716
#
#
# At cv:- 8
# Cross validation score is :- 27.39278093466349
# Accuracy_score is :- 61.5278446577716
#
#
# At cv:- 9
# Cross validation score is :- 29.446480018165623
# Accuracy_score is :- 61.5278446577716

# %% [markdown]
# At cv:- 4
# Cross validation score is :- 40.42198751733842
# Accuracy_score is :- 61.5278446577716

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=4).mean()
print ("The cv score is :- ",lsscore_selected,"\nThe accuracy_score is:",lss)
# Out:
# The cv score is :-  0.4042198751733842
# The accuracy_score is: 0.615278446577716

# %%
MAE= metrics.mean_absolute_error(y_test,pred_test)
MSE= metrics.mean_squared_error(y_test,pred_test)
rmse = sqrt(MSE)

# %%
print("Errors:-")

print("mean absolute error:",MAE)
print("mean squared error:",MSE)
print("Root Mean Squared Error:",rmse)
# Out:
# Errors:-
# mean absolute error: 202.06049549239617
# mean squared error: 130284.62468893411
# Root Mean Squared Error: 360.9496151666242

# %%
print('Difference between Accuracy score and cross validation score is -', abs(accuracy_score - lsscore_selected))
# Out:
# Difference between Accuracy score and cross validation score is - 0.21105857140433182

# %% [markdown]
# # Import other Regression models

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# # DecisionTree Regressor

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train, y_train)
DTR.score(x_train, y_train)
predDTR=DTR.predict(x_test)

dt=r2_score(y_test, predDTR)
print('R2 Score:', dt*100)
# Out:
# R2 Score: 75.18026718728703

# %% [markdown]
# ### Cross validation score

# %%
for i in range(2, 10):
    cv_score = cross_val_score(DTR, x, y, cv=i)
    cv_mean = cv_score.mean()
    
print(f"At cross fold {i}, the Cross Val score is {cv_mean * 100}")
# Out:
# At cross fold 9, the Cross Val score is 60.71164655314527

# %%
dtcvscore=cross_val_score(DTR,x,y,cv=9)
dtcv=dtcvscore.mean()
print('Cross Val Score:', dtcv*100)
# Out:
# Cross Val Score: 62.72835608988733

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,predDTR))
print('Mean Squared Error:', mean_squared_error(y_test,predDTR))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test,predDTR)))
# Out:
# Error:
# Mean Absolute Error: 142.86631640396965
# Mean Squared Error: 84051.16754232341
# Root Mean Square Error: 289.9157938821606

# %%
print('Difference between Accuracy score and cross validation score is -',abs(dt - dtcv))
# Out:
# Difference between Accuracy score and cross validation score is - 0.12451911097399704

# %% [markdown]
# # K-NeighborsRegressor

# %%
kn=KNeighborsRegressor()
kn.fit(x_train, y_train)
kn.score(x_train,y_train)
predkn=kn.predict(x_test)

kn_score= r2_score(y_test, predkn)
print('R2 Score:', kn_score*100)
# Out:
# R2 Score: 64.92206153963623

# %% [markdown]
# ### Cross validation score

# %%
for i in range(2, 10):
    cv_score = cross_val_score(kn, x, y, cv=i)
    cv_mean = cv_score.mean()

print(f"At cross fold {i}, the Cross Val score is {cv_mean * 100}")
# Out:
# At cross fold 9, the Cross Val score is 53.24366727919705

# %%
kn_cvscore=cross_val_score(kn,x,y, cv=9)
kn_cv_mean=kn_cvscore.mean()
print('Cross val Score :',kn_cv_mean*100)
# Out:
# Cross val Score : 53.24366727919705

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,predkn))
print('Mean Squared Error:', mean_squared_error(y_test,predkn))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test,predkn)))
# Out:
# Error:
# Mean Absolute Error: 176.2521891418564
# Mean Squared Error: 118790.22650321074
# Root Mean Square Error: 344.65958060557483

# %%
print('Difference between Accuracy score and cross validation score is -',abs(kn_score - kn_cv_mean))
# Out:
# Difference between Accuracy score and cross validation score is - 0.11678394260439184

# %% [markdown]
# # RandomForestRegressor

# %%
RF=RandomForestRegressor()
RF.fit(x_train, y_train)
RF.score(x_train,y_train)
predRF=RF.predict(x_test)

rf_score= r2_score(y_test, predRF)
print('R2 score:', rf_score*100)
# Out:
# R2 score: 86.2276072396987

# %% [markdown]
# ### Cross validation score

# %%
for i in range(2, 10):
    cv_score = cross_val_score(RF, x, y, cv=i)
    cv_mean = cv_score.mean()

print(f"At cross fold {i}, the Cross Val score is {cv_mean * 100}")
# Out:
# At cross fold 9, the Cross Val score is 79.5244316666394

# %%
rf_cvscore=cross_val_score(RF,x,y, cv=9)
rf_cv_mean=rf_cvscore.mean()
print('Cross val Score :',rf_cv_mean*100)
# Out:
# Cross val Score : 79.3470876192184

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,predRF))
print('Mean Squared Error:', mean_squared_error(y_test,predRF))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test,predRF)))
# Out:
# Error:
# Mean Absolute Error: 112.86611208406306
# Mean Squared Error: 46639.73218768243
# Root Mean Square Error: 215.96233974395264

# %%
print('Difference between Accuracy score and cross validation score is -',abs(rf_score - rf_cv_mean))
# Out:
# Difference between Accuracy score and cross validation score is - 0.06880519620480308

# %% [markdown]
# # GradientBoostingRegressor

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train, y_train)
gb.score(x_train,y_train)
predgb=gb.predict(x_test)

gb_score= r2_score(y_test, predgb)
print('R2 score:', gb_score*100)
# Out:
# R2 score: 87.04209803012222

# %% [markdown]
# ### cross validation score

# %%
for i in range(2, 10):
    cv_score = cross_val_score(gb, x, y, cv=i)
    cv_mean = cv_score.mean()

print(f"At cross fold {i}, the Cross Val score is {cv_mean * 100}")
# Out:
# At cross fold 9, the Cross Val score is 77.22661071728986

# %%
gb_cvscore=cross_val_score(gb,x,y, cv=9)
gb_cv_mean=gb_cvscore.mean()
print('Cross val Score :',gb_cv_mean*100)
# Out:
# Cross val Score : 76.62197590927966

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,predgb))
print('Mean Squared Error:', mean_squared_error(y_test,predgb))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test,predgb)))
# Out:
# Error:
# Mean Absolute Error: 120.64181235180263
# Mean Squared Error: 43881.4872700538
# Root Mean Square Error: 209.47908551942317

# %%
print('Difference between Accuracy score and cross validation score is -',abs(gb_score - gb_cv_mean))
# Out:
# Difference between Accuracy score and cross validation score is - 0.10420122120842557

# %% [markdown]
# # ExtraTreesRegressor

# %%
ET=ExtraTreesRegressor()
ET.fit(x_train, y_train)
ET.score(x_train,y_train)
predET=ET.predict(x_test)

ET_score= r2_score(y_test, predET)
print('R2 score:', ET_score*100)
# Out:
# R2 score: 87.21195339055446

# %% [markdown]
# ### cross validation score

# %%
for i in range(2, 10):
    cv_score = cross_val_score(ET, x, y, cv=i)
    cv_mean = cv_score.mean()

print(f"At cross fold {i}, the Cross Val score is {cv_mean * 100}")
# Out:
# At cross fold 9, the Cross Val score is 81.69395728713472

# %%
ET_cvscore=cross_val_score(ET,x,y, cv=9)
ET_cv_mean=ET_cvscore.mean()
print('Cross val Score :',ET_cv_mean*100)
# Out:
# Cross val Score : 81.04209708121205

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test,predET))
print('Mean Squared Error:', mean_squared_error(y_test,predET))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test,predET)))
# Out:
# Error:
# Mean Absolute Error: 112.54988324576766
# Mean Squared Error: 43306.277961179214
# Root Mean Square Error: 208.10160489813435

# %%
print('Difference between Accuracy score and cross validation score is -',abs(ET_score - ET_cv_mean))
# Out:
# Difference between Accuracy score and cross validation score is - 0.06169856309342403

# %% [markdown]
# # Selection for the best model

# %% [markdown]
# After trying different different regression model we can say that "ExtraTreesRegressor" is the best perfroming model. ExtraTreesRegressor giving us an accuracy of  87.07061326535339 which is highest amnog all the other models & Cross validation score= 81.43525087242152. Difference between Accuracy score and cross validation score is - 0.05635362392931864. which is minimum among all the other regression model. so we select the moel as our best performing model which give us minimum difference between accuracy score and cv score and here ExtraTreesRegressor giving us minimum difference between accuracy score and cv score so we select ExtraTreesRegressor as our final model.

# %% [markdown]
# # Select ExtraTreesRegressor as our final model

# %% [markdown]
# # Perfrom Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameter = {'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],  
    'min_samples_split': [2, 5, 10], 
    'min_samples_leaf': [1, 2, 4],  
}

# %%
GCV=GridSearchCV(ExtraTreesRegressor(),parameter, cv=9)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=9, estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]})

# %%
GCV.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %% [markdown]
# # Final Model

# %%
# Define and train the Extra Trees Classifier
final_model = ExtraTreesRegressor(max_depth=None, min_samples_leaf=4, n_estimators=100, min_samples_split=2)
final_model.fit(x_train, y_train)

# Make predictions
pred = final_model.predict(x_test)

# Calculate and print the r2 score
r2 = r2_score(y_test, pred)
print('R2_score:', r2* 100)
# Out:
# R2_score: 87.20693102863939

# %% [markdown]
# Here we get an accurcy of 86.97%

# %% [markdown]
# # Here we can se that the accuracy is improved by some percentage

# %% [markdown]
# # Saving Final model

# %%
#Saving the model using .pkl
import joblib
joblib.dump(gb,"Zomato_project.pkl")
# Out:
# ['Zomato_project.pkl']

# %% [markdown]
# # predicting the save model

# %%
#Loading the saved model
load=joblib.load("Zomato_project.pkl")


#Predict

prediction = load.predict(x_test)

prediction
# Out:
# array([ 291.32603136,  789.75766319,  272.22237539, ...,  628.94416596,
#         281.12859642, 4007.36805069])

# %%
pd.DataFrame([load.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#         Predicted  Original
# 0      291.326031     400.0
# 1      789.757663     800.0
# 2      272.222375     300.0
# 3      581.372074     500.0
# 4      574.756113     600.0
# ...           ...       ...
# 1708   179.573002     100.0
# 1709  1222.132393    1000.0
# 1710   628.944166     700.0
# 1711   281.128596     300.0
# 1712  4007.368051    4300.0
#
# [1713 rows x 2 columns]

# %% [markdown]
# ## Here we can see that predicted value and original values are almost similiar so we can say that our model is performing well.

# %% [markdown]
# # Lets predict price range

# %%
df
# Out:
#       Restaurant Name  Country Code  City  Locality  Locality Verbose  \
# 0                3321     11.616899    27        98                99
# 1                2794     11.616899    27       376               384
# 2                2550     11.616899    28       185               191
# 3                4150     11.616899    28       549               562
# 4                4878     11.616899    28       549               562
# ...               ...           ...   ...       ...               ...
# 9432             1947     11.616899    13       717               770
# 9433             6352     11.616899    13       736               789
# 9434             4824     11.616899    13       742               795
# 9435             4253     11.616899    13       759               814
# 9436             4767     11.616899    13       759               814
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# 0      7.096817 -2.870154       657                  1100         0
# 1      7.094048 -2.870996       783                  1200         0
# 2      7.102859 -2.869007      1271                  4000         0
# 3      7.102785 -2.868725       794                  1500         0
# 4      7.102998 -2.868788       793                  1500         0
# ...         ...       ...       ...                   ...       ...
# 9432  -2.075973 -0.937919       552                   200         4
# 9433  -2.075747 -0.929022       718                   550         4
# 9434  -2.076865 -0.953334      1364                   445         4
# 9435  -2.074809 -0.954365       719                   400         4
# 9436  -2.074670 -0.951102       715                   160         4
#
#       Has Table booking  Has Online delivery  Is delivering now  Price range  \
# 0                     1                    0                  0     1.385129
# 1                     1                    0                  0     1.385129
# 2                     1                    0                  0     1.744844
# 3                     0                    0                  0     1.744844
# 4                     1                    0                  0     1.744844
# ...                 ...                  ...                ...          ...
# 9432                  0                    0                  0     1.744844
# 9433                  0                    0                  0     1.744844
# 9434                  0                    0                  0     1.744844
# 9435                  0                    0                  0     1.744844
# 9436                  0                    0                  0     1.744844
#
#       Aggregate rating  Rating color  Rating text     Votes  Country
# 0             1.972392             0            1  1.410787        2
# 1             1.649065             0            1  1.753948        2
# 2             1.543945             1            5  1.329422        2
# 3             2.082799             0            1  1.492117        2
# 4             1.972392             0            1  1.240914        2
# ...                ...           ...          ...       ...      ...
# 9432          1.038603             5            2  1.160268        3
# 9433          1.543945             1            5  0.590036        3
# 9434          1.440165             1            5  0.634827        3
# 9435          1.649065             0            1  0.996808        3
# 9436          1.038603             5            2  0.845554        3
#
# [8565 rows x 19 columns]

# %%
plt.figure(figsize=(20,10))
df_new.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# "price range " is highly positively and negatively corelated with "Average cost for two" & "city" and very less corelated with "currency" and "cuisines"

# %%
cor['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Average Cost for two    0.699506
# Votes                   0.523711
# Has Table booking       0.496771
# Aggregate rating        0.429224
# Has Online delivery     0.203256
# Country Code            0.134602
# Country                 0.130354
# Longitude               0.075264
# Restaurant Name         0.064012
# Rating text             0.062516
# Is delivering now       0.030144
# Cuisines                0.027467
# Currency               -0.025634
# Rating color           -0.073294
# Locality Verbose       -0.099217
# Locality               -0.101930
# Latitude               -0.112352
# City                   -0.119901
# Name: Price range, dtype: float64

# %%
# deviding into fetures and target. 
x1=df.drop('Price range', axis=1)
y1=df['Price range']

# %%
x1
# Out:
#       Restaurant Name  Country Code  City  Locality  Locality Verbose  \
# 0                3321     11.616899    27        98                99
# 1                2794     11.616899    27       376               384
# 2                2550     11.616899    28       185               191
# 3                4150     11.616899    28       549               562
# 4                4878     11.616899    28       549               562
# ...               ...           ...   ...       ...               ...
# 9432             1947     11.616899    13       717               770
# 9433             6352     11.616899    13       736               789
# 9434             4824     11.616899    13       742               795
# 9435             4253     11.616899    13       759               814
# 9436             4767     11.616899    13       759               814
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# 0      7.096817 -2.870154       657                  1100         0
# 1      7.094048 -2.870996       783                  1200         0
# 2      7.102859 -2.869007      1271                  4000         0
# 3      7.102785 -2.868725       794                  1500         0
# 4      7.102998 -2.868788       793                  1500         0
# ...         ...       ...       ...                   ...       ...
# 9432  -2.075973 -0.937919       552                   200         4
# 9433  -2.075747 -0.929022       718                   550         4
# 9434  -2.076865 -0.953334      1364                   445         4
# 9435  -2.074809 -0.954365       719                   400         4
# 9436  -2.074670 -0.951102       715                   160         4
#
#       Has Table booking  Has Online delivery  Is delivering now  \
# 0                     1                    0                  0
# 1                     1                    0                  0
# 2                     1                    0                  0
# 3                     0                    0                  0
# 4                     1                    0                  0
# ...                 ...                  ...                ...
# 9432                  0                    0                  0
# 9433                  0                    0                  0
# 9434                  0                    0                  0
# 9435                  0                    0                  0
# 9436                  0                    0                  0
#
#       Aggregate rating  Rating color  Rating text     Votes  Country
# 0             1.972392             0            1  1.410787        2
# 1             1.649065             0            1  1.753948        2
# 2             1.543945             1            5  1.329422        2
# 3             2.082799             0            1  1.492117        2
# 4             1.972392             0            1  1.240914        2
# ...                ...           ...          ...       ...      ...
# 9432          1.038603             5            2  1.160268        3
# 9433          1.543945             1            5  0.590036        3
# 9434          1.440165             1            5  0.634827        3
# 9435          1.649065             0            1  0.996808        3
# 9436          1.038603             5            2  0.845554        3
#
# [8565 rows x 18 columns]

# %%
y1
# Out:
# 0       1.385129
# 1       1.385129
# 2       1.744844
# 3       1.744844
# 4       1.744844
#           ...
# 9432    1.744844
# 9433    1.744844
# 9434    1.744844
# 9435    1.744844
# 9436    1.744844
# Name: Price range, Length: 8565, dtype: float64

# %%
x1.shape
# Out:
# (8565, 18)

# %%
y1.shape
# Out:
# (8565,)

# %% [markdown]
# # Scaling the data Using StandardScaler

# %%
sts=StandardScaler()
x1=sts.fit_transform(x1)

# %%
x1
# Out:
# array([[ 0.0526895 , 11.61690066, -0.49828045, ..., -0.39630978,
#          1.41078655,  7.57004462],
#        [-0.2261454 , 11.61690066, -0.49828045, ..., -0.39630978,
#          1.75394824,  7.57004462],
#        [-0.35524544, 11.61690066, -0.38165553, ...,  2.0854254 ,
#          1.32942197,  7.57004462],
#        ...,
#        [ 0.84792453, 11.61690066, -2.13102921, ...,  2.0854254 ,
#          0.63482701, 11.39639058],
#        [ 0.54580929, 11.61690066, -2.13102921, ..., -0.39630978,
#          0.99680835, 11.39639058],
#        [ 0.81776592, 11.61690066, -2.13102921, ...,  0.22412401,
#          0.84555408, 11.39639058]])

# %% [markdown]
# # Checking for multicollinearity

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
df_col=pd.DataFrame(data=x1, columns=['Restaurant Name', 'Country Code', 'City', 'Locality','Locality Verbose', 'Longitude', 'Latitude', 'Cuisines','Average Cost for two', 'Currency', 'Has Table booking','Has Online delivery', 'Is delivering now','Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'])

# %%
vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(df_col.values, i)
              for i in range(len(df_col.columns))]
vif['Features'] =df_col.columns

vif
# Out:
#     VIF values              Features
# 0     1.008682       Restaurant Name
# 1    15.305703          Country Code
# 2     1.072086                  City
# 3   509.859391              Locality
# 4   509.770022      Locality Verbose
# 5     3.133081             Longitude
# 6     2.762195              Latitude
# 7     1.026738              Cuisines
# 8     1.865809  Average Cost for two
# 9     1.527028              Currency
# 10    1.664885     Has Table booking
# 11    1.247339   Has Online delivery
# 12    1.013725     Is delivering now
# 13    4.729205      Aggregate rating
# 14    1.242213          Rating color
# 15    1.321791           Rating text
# 16    4.910097                 Votes
# 17   13.962254               Country

# %% [markdown]
# We can observe that the vif value is greater than 10 in columns "country code", "Locality", "Locality verbose", "country". If vif value is greater than 10 in that we can say that multicolinearity is present in the dataset and we have to remove it. so we will drop the column with highest vif value and than agian check for the multicolinearity.

# %%
df_col.drop("Locality",axis=1,inplace=True)

# %%
vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(df_col.values, i)
              for i in range(len(df_col.columns))]
vif['Features'] =df_col.columns

vif
# Out:
#     VIF values              Features
# 0     1.008679       Restaurant Name
# 1    15.305233          Country Code
# 2     1.064867                  City
# 3     1.041889      Locality Verbose
# 4     3.132271             Longitude
# 5     2.761917              Latitude
# 6     1.026203              Cuisines
# 7     1.860705  Average Cost for two
# 8     1.526776              Currency
# 9     1.664141     Has Table booking
# 10    1.246855   Has Online delivery
# 11    1.013725     Is delivering now
# 12    4.727788      Aggregate rating
# 13    1.242112          Rating color
# 14    1.321454           Rating text
# 15    4.905669                 Votes
# 16   13.959324               Country

# %%
df_col.drop("Country Code",axis=1,inplace=True)

# %%
vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(df_col.values, i)
              for i in range(len(df_col.columns))]
vif['Features'] =df_col.columns

vif
# Out:
#     VIF values              Features
# 0     1.008496       Restaurant Name
# 1     1.063359                  City
# 2     1.041794      Locality Verbose
# 3     2.881327             Longitude
# 4     2.623662              Latitude
# 5     1.026170              Cuisines
# 6     1.860133  Average Cost for two
# 7     1.516099              Currency
# 8     1.661363     Has Table booking
# 9     1.246851   Has Online delivery
# 10    1.013717     Is delivering now
# 11    4.727779      Aggregate rating
# 12    1.239310          Rating color
# 13    1.320945           Rating text
# 14    4.902233                 Votes
# 15    1.328656               Country

# %% [markdown]
# Here we can see that the vif value is less than 10 for each colun so we can say that multicolinearity is removed from the data set.

# %% [markdown]
# # Model building

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Selection for the best random state

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Convert continuous target variable into categorical labels
y1 = np.digitize(y1, bins=np.histogram(y1, bins='auto')[1])

maxAccu = 0
maxRS = 0

for i in range(1, 200):
    X_train1, X_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=.30, random_state=i)
    mod = RandomForestClassifier()
    mod.fit(X_train1, y_train1)
    pred = mod.predict(X_test1)
    acc = accuracy_score(y_test1, pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i

print("Best accuracy is", maxAccu, "on Random_state", maxRS)
# Out:
# Best accuracy is 0.9883268482490273 on Random_state 46

# %% [markdown]
# # seprating train test split

# %%
X_train1, X_test1, y_train1, y_test1=train_test_split(x1,y1,test_size=.30,random_state=maxRS)

# %% [markdown]
# # RandomForestClassifier

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train1, y_train1)
predRFC=RFC.predict(X_test1)
print('Accuracy Score:',accuracy_score(y_test1, predRFC))
print('Confusion Matrix:',confusion_matrix(y_test1, predRFC))
print(classification_report(y_test1,predRFC))
# Out:
# Accuracy Score: 0.98715953307393
# Confusion Matrix: [[1259    3    0    0]
#  [   7  854    1    0]
#  [   0    6  319    1]
#  [   0    0   15  105]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1262
#           11       0.99      0.99      0.99       862
#           15       0.95      0.98      0.97       326
#           18       0.99      0.88      0.93       120
#
#     accuracy                           0.99      2570
#    macro avg       0.98      0.96      0.97      2570
# weighted avg       0.99      0.99      0.99      2570

# %%
cm = confusion_matrix(y_test1, predRFC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f") 
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %%
#using k-fold cross validation for Random Forest classifier 
cvscore=cross_val_score(RFC,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predRFC) - cvscore.mean()))
# Out:
# [0.84938704 0.96672504 0.99474606 0.99883246 0.95388208]
# 0.9527145359019265
# Difference between Accuracy score and cross validation score is - 0.034444997172003555

# %% [markdown]
# # KNeighborsClassifier

# %%
#checking accuracy for support k-Neighbors classifier

KNN=KNeighborsClassifier()
KNN.fit(X_train1,y_train1)
predKNN= KNN.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predKNN))
print('Confusion Matrix', confusion_matrix(y_test1,predKNN))
print('Classification Report', classification_report(y_test1,predKNN))
# Out:
# Accuracy Score 0.7416342412451362
# Confusion Matrix [[1101  157    4    0]
#  [ 271  542   49    0]
#  [  10  115  196    5]
#  [   0    3   50   67]]
# Classification Report               precision    recall  f1-score   support
#
#            1       0.80      0.87      0.83      1262
#           11       0.66      0.63      0.65       862
#           15       0.66      0.60      0.63       326
#           18       0.93      0.56      0.70       120
#
#     accuracy                           0.74      2570
#    macro avg       0.76      0.67      0.70      2570
# weighted avg       0.74      0.74      0.74      2570

# %%
cm = confusion_matrix(y_test1, predKNN)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", cmap="Purples") 
plt.title('Confusion Matrix for K-Neighbors Classifier')
plt.show()

# %%
#using k-fold cross validation for k-Neighbour classifier 
cvscore=cross_val_score(KNN,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predKNN) - cvscore.mean()))
# Out:
# [0.57034442 0.56042032 0.69118506 0.76298891 0.70052539]
# 0.657092819614711
# Difference between Accuracy score and cross validation score is - 0.08454142163042522

# %% [markdown]
# # DecisionTreeClassifier

# %%
#checking accuracy for DecisionTreeclassifier
DTC=DecisionTreeClassifier()
DTC.fit(X_train1, y_train1)
predDTC=DTC.predict(X_test1)
print('Accuracy Score',accuracy_score(y_test1, predDTC))
print('Confusion Matrix',confusion_matrix(y_test1, predDTC))
print('Classification Report',classification_report(y_test1,predDTC))
# Out:
# Accuracy Score 0.9836575875486381
# Confusion Matrix [[1254    8    0    0]
#  [   3  847   12    0]
#  [   0    6  313    7]
#  [   0    0    6  114]]
# Classification Report               precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00      1262
#           11       0.98      0.98      0.98       862
#           15       0.95      0.96      0.95       326
#           18       0.94      0.95      0.95       120
#
#     accuracy                           0.98      2570
#    macro avg       0.97      0.97      0.97      2570
# weighted avg       0.98      0.98      0.98      2570

# %%
cm = confusion_matrix(y_test1, predDTC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f",  cmap="Purples") 
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %%
#using k-fold cross validation for decision tree classifier 
cvscore=cross_val_score(DTC,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predDTC) - cvscore.mean()))
# Out:
# [0.56392294 0.96322242 1.         0.99883246 0.94220665]
# 0.8936368943374197
# Difference between Accuracy score and cross validation score is - 0.09002069321121842

# %% [markdown]
# # SupportVectorClassifier

# %%
#checking accuracy for support vector machine classifier

svc=SVC()
svc.fit(X_train1,y_train1)
predsvc= svc.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predsvc))
print('Confusion Matrix', confusion_matrix(y_test1,predsvc))
print('Classification Report', classification_report(y_test1,predsvc))
# Out:
# Accuracy Score 0.9412451361867704
# Confusion Matrix [[1232   30    0    0]
#  [  46  803   13    0]
#  [   0   33  286    7]
#  [   0    0   22   98]]
# Classification Report               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97      1262
#           11       0.93      0.93      0.93       862
#           15       0.89      0.88      0.88       326
#           18       0.93      0.82      0.87       120
#
#     accuracy                           0.94      2570
#    macro avg       0.93      0.90      0.91      2570
# weighted avg       0.94      0.94      0.94      2570

# %%
cm = confusion_matrix(y_test1, predsvc)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", cmap="ocean") 
plt.title('Confusion Matrix for Support Vector Classifier')
plt.show()

# %%
#using k-fold cross validation for support vector classifier 
cvscore=cross_val_score(svc,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predsvc) - cvscore.mean()))
# Out:
# [0.76065382 0.87157034 0.931115   0.95037945 0.90309399]
# 0.8833625218914186
# Difference between Accuracy score and cross validation score is - 0.0578826142953518

# %% [markdown]
# # GradientBoostingClassifier

# %%
#checking accuracy for gradient boosting classifier
GB=GradientBoostingClassifier()
GB.fit(X_train1,y_train1)
predGB=GB.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predGB))
print('Confusion Matrix', confusion_matrix(y_test1,predGB))
print('Classification Report', classification_report(y_test1,predGB))
# Out:
# Accuracy Score 0.988715953307393
# Confusion Matrix [[1259    3    0    0]
#  [   4  857    1    0]
#  [   0   12  312    2]
#  [   0    0    7  113]]
# Classification Report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1262
#           11       0.98      0.99      0.99       862
#           15       0.97      0.96      0.97       326
#           18       0.98      0.94      0.96       120
#
#     accuracy                           0.99      2570
#    macro avg       0.98      0.97      0.98      2570
# weighted avg       0.99      0.99      0.99      2570

# %%
cm = confusion_matrix(y_test1, predGB)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f") 
plt.title('Confusion Matrix for Gradient Boosting Classifier')
plt.show()

# %%
#using k-fold cross validation for Gradient Boosting classifier 
cvscore=cross_val_score(GB,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predGB) - cvscore.mean()))
# Out:
# [0.56509048 0.95855225 0.99941623 1.         0.96030356]
# 0.8966725043782837
# Difference between Accuracy score and cross validation score is - 0.09204344892910932

# %% [markdown]
# # AdaBoostClassifier

# %%
#checking accuracy for AdaBoost Classifier
ABC=AdaBoostClassifier()
ABC.fit(X_train1, y_train1)
predABC=ABC.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predABC))
print('Confusion Matrix', confusion_matrix(y_test1,predABC))
print('Classification Report', classification_report(y_test1,predABC))
# Out:
# Accuracy Score 0.8252918287937743
# Confusion Matrix [[1262    0    0    0]
#  [  17  845    0    0]
#  [   0  319    5    2]
#  [   0  110    1    9]]
# Classification Report               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1262
#           11       0.66      0.98      0.79       862
#           15       0.83      0.02      0.03       326
#           18       0.82      0.07      0.14       120
#
#     accuracy                           0.83      2570
#    macro avg       0.83      0.52      0.49      2570
# weighted avg       0.85      0.83      0.76      2570

# %%
cm = confusion_matrix(y_test1, predABC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f",cmap="Purples" ) 
plt.title('Confusion Matrix for AdaBoost Classifier')
plt.show()

# %%
#using k-fold cross validation for Adaboost classifier 
cvscore=cross_val_score(ABC,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predABC) - cvscore.mean()))
# Out:
# [0.26269702 0.82078225 0.83070636 0.83070636 0.82136602]
# 0.7132516053706948
# Difference between Accuracy score and cross validation score is - 0.11204022342307951

# %% [markdown]
# # BaggingClassifier

# %%
#checking accuracy for Bagging classifier

BC=BaggingClassifier()
BC.fit(X_train1,y_train1)
predBC= BC.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predBC))
print('Confusion Matrix', confusion_matrix(y_test1,predBC))
print('Classification Report', classification_report(y_test1,predBC))
# Out:
# Accuracy Score 0.9875486381322958
# Confusion Matrix [[1258    4    0    0]
#  [   2  858    2    0]
#  [   0    9  312    5]
#  [   0    0   10  110]]
# Classification Report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1262
#           11       0.99      1.00      0.99       862
#           15       0.96      0.96      0.96       326
#           18       0.96      0.92      0.94       120
#
#     accuracy                           0.99      2570
#    macro avg       0.98      0.97      0.97      2570
# weighted avg       0.99      0.99      0.99      2570

# %%
cm = confusion_matrix(y_test1, predBC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f" ) 
plt.title('Confusion Matrix for AdaBoost Classifier')
plt.show()

# %%
#using k-fold cross validation for Bagging classifier 
cvscore=cross_val_score(BC,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predBC) - cvscore.mean()))
# Out:
# [0.56800934 0.95329831 1.         0.99883246 0.94979568]
# 0.8939871570344426
# Difference between Accuracy score and cross validation score is - 0.09356148109785312

# %% [markdown]
# # ExtraTreesClassifier

# %%
#checking accuracy for ExtraTreesclassifier

ET=ExtraTreesClassifier()
ET.fit(X_train1,y_train1)
predET= ET.predict(X_test1)
print('Accuracy Score', accuracy_score(y_test1,predET))
print('Confusion Matrix', confusion_matrix(y_test1,predET))
print('Classification Report', classification_report(y_test1,predET))
# Out:
# Accuracy Score 0.9490272373540856
# Confusion Matrix [[1240   22    0    0]
#  [  24  820   18    0]
#  [   0   32  287    7]
#  [   0    0   28   92]]
# Classification Report               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98      1262
#           11       0.94      0.95      0.94       862
#           15       0.86      0.88      0.87       326
#           18       0.93      0.77      0.84       120
#
#     accuracy                           0.95      2570
#    macro avg       0.93      0.90      0.91      2570
# weighted avg       0.95      0.95      0.95      2570

# %%
cm = confusion_matrix(y_test1, predET)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f" ) 
plt.title('Confusion Matrix for AdaBoost Classifier')
plt.show()

# %%
#using k-fold cross validation for Bagging classifier 
cvscore=cross_val_score(ET,x1,y1,cv=5)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test1,predET) - cvscore.mean()))
# Out:
# [0.5364857  0.81961471 0.91593695 0.95037945 0.90659661]
# 0.8258026853473439
# Difference between Accuracy score and cross validation score is - 0.12322455200674165

# %% [markdown]
# # Selection of final model

# %% [markdown]
# After trying different different classification model here we reach at the conclusion that SupportVectorClassifier is our final model because when we have applied the SupportVectorClassifier we got an accuracy of 0.9412451361867704 and to over come overfitting and underfitting issue we use cross validation and get cross validation score of 0.8833625218914186 and we find Difference between Accuracy score and cross validation score that is equal to 0.0578826142953518. so we select that model as our final model which has higher accuracy score and higher cross validation score and has lowest difference between between accuracy score and cross validation score. here SupportVectorClassifier fullfills all our requriment so we select SupportVectorClassifier as our final model.

# %% [markdown]
# # Select SupportVectorClassifier as our final model

# %% [markdown]
# # Perfrom Hyperparameter Tuning for SupportVectorClassifier

# %%
from sklearn.model_selection import GridSearchCV

parameter = {'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']}

# %%
GCV=GridSearchCV(SVC(),parameter, cv=5)

# %%
GCV.fit(X_train1,y_train1)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']})

# %%
GCV.best_params_
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# # Final Model

# %%
# Define and train the Extra Trees Classifier
final_model = SVC(C=10, gamma='scale', kernel='linear')
final_model.fit(X_train1, y_train1)

# Make predictions
pred = final_model.predict(X_test1)

# Calculate and print the accuracy score
accuracy = accuracy_score(y_test1, pred)
print('Accuracy:', accuracy * 100)
# Out:
# Accuracy: 97.43190661478599

# %% [markdown]
# We got an accuracy of 97.43%

# %% [markdown]
# # Auc-Roc curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
import numpy as np

# Extract unique classes from the target variable
unique_classes = np.unique(y_train1)

# Get the number of classes
n_classes = len(unique_classes)

# Print the number of classes
print("Number of classes:", n_classes)
# Out:
# Number of classes: 4

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Binarize the target variable for each class
y_test1_bin = label_binarize(y_test1, classes=range(n_classes))

# Get predicted probabilities for each class
y_pred_prob = final_model.decision_function(X_test1)

# Calculate ROC curves and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test1_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Calculate overall AUC
mean_auc = np.mean(list(roc_auc.values()))
print('Mean AUC:', mean_auc)
# Out:
# Mean AUC: nan

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve, auc

# Create the OvR classifier for KNN
ovr_classifier = OneVsRestClassifier(KNN)

# Fit the classifier on the training data
ovr_classifier.fit(X_train1, y_train1)

# Predict probabilities for each class
y_pred_prob = ovr_classifier.predict_proba(X_test1)

# Compute ROC curve and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test1_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Saving the best model

# %%
import joblib

joblib.dump(final_model, 'zomato_project_price_range.pkl')
# Out:
# ['zomato_project_price_range.pkl']

# %% [markdown]
# # Conclusion

# %% [markdown]
# Here we can say that for price range supportvectorclassifier is working well
